# %%
import urllib.request
import json
import datetime

# %%
def gen_search_url(api_node, search_text, start_num, disp_num):
    base = 'https://openapi.naver.com/v1/search'
    node = '/' + api_node + '.json'
    param_query = '?query=' + urllib.parse.quote(search_text)
    param_start = '&start=' + str(start_num)
    param_disp = '&display=' + str(disp_num)
    
    return base + node + param_query + param_start + param_disp

# %%
def get_result_onpage(url):
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    
    response = urllib.request.urlopen(request)
    
    print('[%s] Url Request Success' % datetime.datetime.now())
    return json.loads(response.read().decode('utf-8'))

# %%
client_id = "jOc7UxR_Sp1MMk2mwOq1"
client_secret = "s9PY8Vl3Wz"

url = gen_search_url('kin', '파이썬', 1, 100)
one_result = get_result_onpage(url)
one_result
# Out:
# [2021-12-05 18:26:37.259865] Url Request Success
# {'lastBuildDate': 'Sun, 05 Dec 2021 18:26:37 +0900',
#  'total': 208701,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '<b>파이썬</b>, C언어 공부 질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=406046940&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=1&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>은 백준 기준으로 브론즈는 웬만큼 풀 줄 알게 되었고... <b>파이썬</b> 공부는 앞으로 어떻게 해나가면 좋을지 잘 모르겠습니다. 아직은 <b>파이썬</b> 초보라고 생각하기에 초보에게... <b>파이썬</b>과 C언어를 공부하고 계신데요. 기본적으로... '},
#   {'title': '<b>파이썬</b> 문제',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=406201342&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=2&search_sort=0&spq=0',
#    'description': "<b>파이썬</b> 문제 해결  import turtle print('이 프로그램은 다각형') d = 100 while True: n = input('원하는 다각형(3,4,5 종료:x) ') x,y = map(int,input('위치 x,y ').split(',')) turtle.penup() turtle.... "},
#   {'title': '<b>파이썬</b> 코딩 도와주세요',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=405927192&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=3&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 코딩 이거 어떻게 하는지 알려주세요 ㅠㅜ 내공 50이요!! def Pyung2msq(value): return value * 3.3 def Msq2pyung(value): return value / 3.3 def Cm2inch(value): return value * 0.394 def Inch2cm(value)... '},
#   {'title': '<b>파이썬</b> 코딩 질문이요 ㅠㅜ !',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=405623778&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=4&search_sort=0&spq=0',
#    'description': "저기 밑에 SELF STUDY 부분 <b>파이썬</b> 코딩 이거 어떻게 하는지 알려주세요 ㅠㅜ 내공 100이요 !!! ss = '<b>파이썬</b>은완전재미있어요' sslen = len(ss) for i in range(0 , sslen) : if i % 2 == 0 : print(ss[i], end='') else... "},
#   {'title': '<b>파이썬</b> for, while문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=405173440&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=5&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> for, while문 연습문제로 나와있는 건데요 위 그림 순서대로 (1),(2),(3),(4) 차례로... D:\\<b>파이썬</b>코드\\test... '},
#   {'title': '<b>파이썬</b> 문제의 답 알려주세요%%',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=406326346&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=6&search_sort=0&spq=0',
#    'description': "<b>파이썬</b> 문제의 답 알려주세요%%  이렇게인 듯? import time now = time.time() sum = 0 for i in range(10000000): sum += 1 passed_time = time.time() - now print(f'계산 소요 시간: {passed_time:.5f}초')"},
#   {'title': '<b>파이썬</b>에서 &amp;은 뭔가요?',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=406180548&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=7&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>에서 &amp;은 뭔가요? &amp;는 bitwise AND라고 해서 2진수숫자들끼리 각 자릿수를 AND를 하는겁니다. 예로 들어 a = 14 b = 4 print(b &amp; a) # 4를 출력. 0000 1110 (14) &amp; 0000 0100 (4) = 0000 0100 '},
#   {'title': '마인크래프트 <b>파이썬</b> (내공 50)(주의 : be임)',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=2&dirId=20411&docId=403073485&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=8&search_sort=0&spq=0',
#    'description': '마인크래프트 <b>파이썬</b>을 배워보고 싶은데 배울 곳 없나요? 그리고 그걸 적용하는 방법과 앱까지 알 수 있는 곳... 답변: be는 <b>파이썬</b>과 관련 없으므로 php 를 배워야 합니다. 구글에서 php 를 검색하고 유튜브 강좌를 이용하세요.... '},
#   {'title': '코딩 <b>파이썬</b> 질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=405999991&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=9&search_sort=0&spq=0',
#    'description': '버튼을 이용하여 count up, count down, <b>파이썬</b> 종료하는 윈도우... text=&quot;<b>파이썬</b> 종료&quot;,fg=&quot;red&quot;,command = quit) button2 = Button(window... config(text=str(number)) button1 = Button(window, text=&quot;<b>파이썬</b> 종료... '},
#   {'title': '<b>파이썬</b> 코딩',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=404141529&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=10&search_sort=0&spq=0',
#    'description': "... 로 출력되게 <b>파이썬</b>에서 코딩하려면 어떻게 해야하나요ㅜㅠ? 질문의 정확한 의도를 잘 모르지만........ def f(n) : A=2*(n-1)-1 print(f'A는 {A}입니다.') f(10) ====================== RESTART: D:\\python39\\1.py... "},
#   {'title': '<b>파이썬</b>으로 만들 수 있는 간단한',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1040201&docId=405486928&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=11&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>으로 만들 수 있는 짧으면서 간단한 인공지능 알려주세요. &quot;짧으면서 간단&quot;한 이라는 게 사람마다... <b>파이썬</b> Python Macro 구현 pyautogui 이미지 인식하여 마우스 컨트롤 하는 법 + opencv-python (tistory.com) 만들어진... '},
#   {'title': '<b>파이썬</b> 노트북 환경',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1118&docId=405068278&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=12&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 구동을 위해 갖추어야 할 노트북 환경은 어떻게 되나요? 노트북을 구매할 때 고려해야 할 사항이 무엇인지... <b>파이썬</b>을 배우고 있는 중이라면 당장은 그렇게 좋은 사양의 노트북은 필요 없습니다. 하지만 실력이 좋아지고 다른... '},
#   {'title': '<b>파이썬</b> 라이브러리',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=404633565&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=13&search_sort=0&spq=0',
#    'description': '... <b>파이썬</b>라이버러리는 어디서 다운받을수가 있나요 라이브러리라는 뜻은 특정 기능을 만들어서 공통으로 다른... 일반적으로 <b>파이썬</b>의 라이브러리는 pip 이라는 명령으로 설치를 하는데요. (이른바 공인된 라이브러리) 수학적인... '},
#   {'title': '<b>파이썬</b>인강 잘 아시는 분 알려주세요.',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=406297856&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=14&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>인강이 필요해서 알아보고 있었는데요. 오프라인... <b>파이썬</b>를 인강으로 배울 수 있게끔 잘 구성되어... <b>파이썬</b>인강으로 쫌 유명한 홈페이지나, 학원이 있다면... <b>파이썬</b>인강을 알아보고 계신다면 딱 좋은 학원강의가 있어서... '},
#   {'title': '사랑의 방정식 <b>파이썬</b>',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=403682488&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=15&search_sort=0&spq=0',
#    'description': "사랑의 방정식을 <b>파이썬</b>으로 돌릴 수는 없나요? 함수 축이 나오는 것까진 했는데... axis('equal') plt.plot(x, y) plt.title('fifth heart curve | parametric equations') plt.show() #<b>파이썬</b> #python "},
#   {'title': '<b>파이썬</b> 질문 ? [500]',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=404752358&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=16&search_sort=0&spq=0',
#    'description': '... <b>파이썬</b>으로 가능한가요? 안되면 무슨 언어로 하는 게 가장 편한가요? <b>파이썬</b>으로 pystray 모듈을 사용하여 간편하게 만들수 있습니다. 아래 코드 실행해보세요. 더 많은 것이 궁금하시면... '},
#   {'title': '<b>파이썬</b> 질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=406243883&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=17&search_sort=0&spq=0',
#    'description': "<b>파이썬</b>에서 텍스트에 특정 단어 여부를 알아내는 알고리즘을 만들고 싶은데 단어가 한글일 때 어떻게 해야 할까요..? s = 'show me the money' a = 'me' b = 'THE' if a in s : print('있음') else : print('없음') if b in... "},
#   {'title': 'Vscode <b>파이썬</b> 급해요',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=405346081&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=18&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> vscode로 독학해서 배우고 잇는데 <b>파이썬</b> 코드 실행이 안됩니다. 실행 버튼이 있긴한데 다른 영상들과... 전문가분들 도와주세요 ㅜㅜ  처음 <b>파이썬</b> 하시는 것이라면 vscode에서 하시는 것보다는 IDLE에서 하세요. <b>파이썬</b>을... '},
#   {'title': '현재 프로그래밍 언어 <b>파이썬</b>이 제일 쉽나요?',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=405797109&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=19&search_sort=0&spq=0',
#    'description': '몇년전에 <b>파이썬</b>이 제일 쉽다고 들은 것 같은데 요즘도 그러나요?  코딩을 처음 접하는 초보자분들이 <b>파이썬</b>으로 코딩공부를 가장 많이 시작하십니다. https://blog.naver.com/95shinha/222490214649'},
#   {'title': '<b>파이썬</b> 코딩 질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=406065720&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=20&search_sort=0&spq=0',
#    'description': '... <b>파이썬</b> 입문자 입니다 연습문제로 풀어보려고 하는게 너무 어려워서 한번 여쭤봅니다. 조건은... argv[1:] main(args) 실행 이런 형태로 입력하는데 저의 <b>파이썬</b> 파일은 k_23.py였어요. 작성자님은 알맞게... '},
#   {'title': '<b>파이썬</b> 질문있어요',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=403482963&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=21&search_sort=0&spq=0',
#    'description': '[퀴즈1,퀴즈2, 퀴즈3] 이렇게 해서 코드를 짠다음에 퀴즈1를 고르면 그 퀴즈가 나오는 그런 코드는 <b>파이썬</b>에서는 못짜나요?? 짤수 있다면 알려주실 수 있을까요? 제가 가진 내공을 다 걸께요ㅜㅠ <b>파이썬</b>에서 지원하는 데이터... '},
#   {'title': '<b>파이썬</b> 질문 드립니다.',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=406027869&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=22&search_sort=0&spq=0',
#    'description': '... <b>파이썬</b> 관련 한가지 질문을 드립니다. 제가 Jupiter Notebook을 사용하고 있습니다. 그리고 저한테... 제가 아직 <b>파이썬</b>을 공부한지 얼마 안된 초보자라 잘 모르겠습니다. 어떤 식으로 해야하는지... '},
#   {'title': '<b>파이썬</b>공부 , 정보기사처리 자격증공부',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=404903229&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=23&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 공부를 먼저 해야할까요 아니면 자격증 공부하고 <b>파이썬</b>으로 넘어가는게 좋을까요? 응시자격조건은... <b>파이썬</b> 책과 <b>파이썬</b> 인강 병행해서 공부하시는 걸 추천드립니다. 궁금한 점은 블로그 통해 글 남겨주세요.'},
#   {'title': '<b>파이썬</b> 인공지능',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=404905731&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=24&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>을 이용한 인공지능이 있을까요? <b>파이썬</b>으로 어떤 인공지능을 만들 수 있나요? <b>파이썬</b>(코딩)도... 안녕하세요, 메가 IT 진로담당컨설턴트 신짱입니다~~ 인공지능 기술의 기반이 되는 프로그래밍언어가 <b>파이썬</b>입니다... '},
#   {'title': '<b>파이썬</b> 질문드립니다!',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=404262848&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=25&search_sort=0&spq=0',
#    'description': "임의의 숫자를 입력받아서 그 숫자들의 합계와 각 숫자들의 비율을 나타내는 <b>파이썬</b> 구현할 수 있을까요? ex) 입력받은 시간이 1,2,3 이라면 합계 = 6 a = 17 b = 33 c = 50 a = int(input('수1을 입력하세요 : ')) b... "},
#   {'title': '<b>파이썬</b>에서 enumerate 질문이요',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=393495506&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=26&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>에서 enumerate는 언제 사용하나요? enumerate() 함수는 주로... (5,300) ※ 질문주신 내용 이외에도, <b>파이썬</b>과 관련하여 궁금한... 참고하시기 바랍니다 :D https://dinolabs.tistory.com/category/BLOG/<b>파이썬</b> 기초 '},
#   {'title': '<b>파이썬</b>독학 할수있을까요?',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10406&docId=403030497&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=27&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>독학 해도 괜찮을까요? 제가 <b>파이썬</b>독학을 해볼까 했는데 좀 힘든거 같아서 독학 안하고 도움을 받을곳에서... 배워야 <b>파이썬</b>독학 할때보다 더 좋을까요? <b>파이썬</b>독학 하는것보다는 배우는게 더 도움이 될거 같은데 혼자 독학하다가... '},
#   {'title': '<b>파이썬</b> 코드',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=406538112&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=28&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>을 잘몰라서 질문합니다. <b>파이썬</b>으로 작성한 코드를 열람이나... 안녕하세요 <b>파이썬</b>으로 작성한 프로그램을 다른 사람들이 해당 프로그램의... pyinstaller는 <b>파이썬</b> 프로그램을 exe파일로 변환을 해 주는 모듈이기 때문에... '},
#   {'title': '<b>파이썬</b>잘하는분',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=403161670&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=29&search_sort=0&spq=0',
#    'description': '... <b>파이썬</b> 세계로 오신걸 환영합니다. <b>파이썬</b>은 비단뱀 처럼 매력적인 언어입니다.&quot;&quot;&quot; cnt=0... <b>파이썬</b> 세계로 오신걸 환영합니다. <b>파이썬</b>은 비단뱀 처럼 매력적인 언어입니다.&quot;&quot;&quot; cnt = 0... '},
#   {'title': '<b>파이썬</b> 속도',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=393706735&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=30&search_sort=0&spq=0',
#    'description': '... <b>파이썬</b>의 속도는 c, java에 비교하면 어느정돈가요? <b>파이썬</b>의 속도를 1이라 가정했을때 c, java의 수치는? 2. <b>파이썬</b>은 1초에 연산을 몇번하나요? 1. https... <b>파이썬</b>은 c에 비해서 71.90 배 느린 속도로 연산을 합니다. 저... '},
#   {'title': '<b>파이썬</b> 함수',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=403316086&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=31&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>으로 def 함수 하고 있는데 사진처럼 계속 오류가 나요 왜 그런건가요?? 계속 IDLE에서만 하다가 <b>파이썬</b>으로 직접하는데 이러내요 IDLE에서는 오류가 안 나는데 <b>파이썬</b>으로만 하면 오류가... '},
#   {'title': '<b>파이썬</b> 질문합니다 ㅜㅜ',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=402986476&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=32&search_sort=0&spq=0',
#    'description': "이거 <b>파이썬</b> 어떻게 작성하나요ㅜㅜ from turtle import * import math r = int(input('반지름 ')) while True: d = int(input('도형 ')) if d &gt;= 3 and d &lt;=6: break x = int(input('원 둘레 ')) if x : circle... "},
#   {'title': '<b>파이썬</b> 질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=402649677&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=33&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 임의의 난수 질문드립니다! https://kin.naver.com/qna/detail.nhn?d1id=1&amp;dirId=1040201&amp;docId=401830375&amp;page=1#answer1 제가 답변하여 채택된 글입니다. 동일한 문제집 같습니다. '},
#   {'title': '<b>파이썬</b>(인공지능, AI 등)으로 IT회사 창업 아이템',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10401&docId=404614990&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=34&search_sort=0&spq=0',
#    'description': '... 혹시 <b>파이썬</b>도 위와 같이 창업을 할 수 있는 방법(?)이 뭐가... 또한 웹이나 앱은 1인 개발이 가능한데 <b>파이썬</b>으로 1인 개발로... <b>파이썬</b>을 활용한 1인 창업을 고민하고 계신데요. <b>파이썬</b>도 Django 프레임워크를 활용하면 웹 개발을 할 수... '},
#   {'title': '<b>파이썬</b> 메모장 불러오기',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=392003761&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=35&search_sort=0&spq=0',
#    'description': '메모장에 <b>파이썬</b>에서 실행해야할 명령을 적어놓고 저장해놓았다가 <b>파이썬</b>에 이를 가져와서 실행하고 싶은데 어떻게 해야하나요? 질문 내용을 보아 <b>파이썬</b> 코딩을 메모장에서 할 수 있느냐는 질문으로 보입니다. 메모장에서 아래와... '},
#   {'title': '<b>파이썬</b> 질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=405008008&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=36&search_sort=0&spq=0',
#    'description': '제가 <b>파이썬</b>을 공부하고 있는데 <b>파이썬</b> 파일과 같은 위치에 &quot;a.txt&quot;라는 파일을 만들고 싶어요. 근데 만약 이미 있으면 만들 필요가 없어서 실행시키지 않고 싶은데 이걸 어떻게 할까요? if문을 쓰면... '},
#   {'title': '<b>파이썬</b> 오류 질문드립니다',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=406159631&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=37&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 질문드려요 ㅠㅠㅠ 길이 단위 변환하는 프로그램을 <b>파이썬</b>으로 하고 있는데 출력을 하려고 하면 자꾸 dongDic이 정의되지 않았다고 오류가 나오네요,,, ㅠㅠㅠㅠ 어떤 부분이 오류인가요... DongUnit 함수에는 mm를... '},
#   {'title': '<b>파이썬</b> 질문이요',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=404005537&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=38&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 도형 그리기 각도 계산하는 법 알려주세요 삼각형/사각형/오각형 부탁드립니다. turtle.circle(&lt;반지름 길이&gt;,360,&lt;꼭짓점 개수&gt;) 위와 같이 입력하면 정다각형을 그립니다. #<b>파이썬</b> #python '},
#   {'title': '<b>파이썬</b> +=',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=403357489&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=39&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>에서 += 를 어떻게 읽나요?  전제이름은 복합연산자, 복합 대입 연산자 입니다 세부 이름은 모르겠네요. 자신에 더하기 하기?'},
#   {'title': '안녕하세요 아까 <b>파이썬</b> 이진법 1대1 질문드립니다',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=403095570&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=40&search_sort=0&spq=0',
#    'description': '아직 제가 <b>파이썬</b>에 대해 잘 몰라서 어디가 틀린지... <b>파이썬</b>을 이제 막 대학교에서 처음 배우고 있는데 숙제를... 시험도 이제 한 달 밖에 안 남았는데 <b>파이썬</b>은 벼락치기... <b>파이썬</b> 자체는 어려운 프로그래밍 언어는 아닙니다. 다만... '},
#   {'title': '<b>파이썬</b> 질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=405558693&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=41&search_sort=0&spq=0',
#    'description': '학교 정보 수행이 <b>파이썬</b>으로 뭐를 만들어 오라고 하셨는데 하나도 모르겠어서...<b>파이썬</b> 리스트로 간단한 예문 하나만 만들어 주심 감사하겠습니다.내공 50 걸게요. 가능한 빨리 부탁드립니다.  import... '},
#   {'title': '<b>파이썬</b> 풀이 질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=402642343&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=42&search_sort=0&spq=0',
#    'description': "<b>파이썬</b> 홐자서 공부하는중인데 4-22, 23을 못풀겠습니다 도와주세요 # 4.22 import datetime date = datetime.datetime.now() y, m, d = date.year, date.month, date.day print(f'현재 시간은 {y}년 {m}월 {d}... "},
#   {'title': '<b>파이썬</b> 왜 : 안쓰고 ; 쓰는 이유??',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=403759698&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=43&search_sort=0&spq=0',
#    'description': '; 를 <b>파이썬</b>에서 왜 사용하는지 역할이 뭔지 알려주세요 보통 프로그래밍 언어에서 세미콜론의 역할은 그 문장의 종료를 나타냅니다. <b>파이썬</b>같은 경우는 굳이 안써도 되지만... 그냥 실수로 쓴 것 같아 보입니다. '},
#   {'title': '<b>파이썬</b> 고수 있나요',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=403406326&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=44&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 공부 중입니다. <b>파이썬</b>은 원래 오타 한번 나서 오류 나면 첨부터 다시 써야 되나요?? 씨플플이나 자바는... IDLE같은 <b>파이썬</b> 셸에서 하기 때문입니다. IDLE같은 경우에는 셸에서 하지마세요. 셸은 아래의 사진같은 화면입니다.... '},
#   {'title': '<b>파이썬</b>으로 이것도 가능한가요?',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=404293411&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=45&search_sort=0&spq=0',
#    'description': '... <b>파이썬</b>으로 데이터 분석 등을 할 수 있다고도 하고 반복작업을 할 수 있다고 하는데 혹시 엑셀파일로 정리된... 것도 <b>파이썬</b>으로 자동 등록 할 수 있는건가요? 웹스크래핑, 크롤링으로 가능한 내용입니다. 데이터 분석도 pandas 를... '},
#   {'title': '<b>파이썬</b> 질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=406419360&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=46&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 실습인데 특수문자를 어떻게 공백으로 바꾸어요?ㅜㅜ  음 이런걸 말하는건가요? sp = &quot;~!@#$%^&amp;*-_+=(){}:;?.,&lt;&gt;&quot; inputStr = input() outputStr = &quot;&quot; for s in inputStr: if s in sp: outputStr += &quot; &quot; else... '},
#   {'title': '<b>파이썬</b> 코딩 설명부탁드려요',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=403108851&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=47&search_sort=0&spq=0',
#    'description': '사진에 있는 <b>파이썬</b> 코딩 최대한 자세하게 설명부탁드려요 가장 이해가 안 되는 부분은 import 아래의 l=[ ] 이 부분이 어떻게 쓰여지는 건지 모르겠어요 나머지 부분도 설명부탁드립니다!! # 랜덤 모듈 생성 import... '},
#   {'title': '<b>파이썬</b> 코딩',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=402980813&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=48&search_sort=0&spq=0',
#    'description': "<b>파이썬</b>으로 * ** *** **** ***** ****** ******* 이거 코딩 어떻게 해야 하나요? for랑 while 둘 다 알려주세요ㅠㅠㅠㅠㅠ  for i in range(7): print(' '*(6-i),end='') print('* '*(i+1))"},
#   {'title': '<b>파이썬</b> 점수 출력',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=401988255&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=49&search_sort=0&spq=0',
#    'description': "... 도와주세요 ㅜㅜ <b>파이썬</b> 잘하시는 분들 제발... score = int(input('기초<b>파이썬</b> 예상 점수 : ')) if score &gt;= 95: print('당신의 기초<b>파이썬</b> 학점은 A+ 입니다.') elif score &gt;= 90: print('당신의 기초<b>파이썬</b> 학점은 A... "},
#   {'title': '<b>파이썬</b> 문제를 푸는데 이해가 되지 않습니다…',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=403679825&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=50&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 공부를 하는데 계속 오류가 뜨더라구요. avg안에 들어갈 값하고 7번째 줄에서 계속 오류가... 98이 나와야 하는데 에러만 뜨네요… raise 는 <b>파이썬</b>에서 예외를 발생시키기 위한 키워드 입니다.... '},
#   {'title': '<b>파이썬</b>관련 (오픈소스?) 저작권에 대해서',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60205&docId=402471882&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=51&search_sort=0&spq=0',
#    'description': '... 최근 <b>파이썬</b> 언어에 관심이 생겨 학습중인 학생입니다. 최근... 저는 <b>파이썬</b>을 무료로 받아서 사용하고 있는데 이것은... 제가 만약 무료인 <b>파이썬</b>을 사용해서 모듈이나 소프트웨어를 제작한다면, 제가 제작한 제작물은 <b>파이썬</b>... '},
#   {'title': '윈도우7 <b>파이썬</b>',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=401920467&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=52&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 설치를 하려고 하는데 최신 버전은 10이상만 된다고 하네요..윈도우7에 <b>파이썬</b> 설치하려면 전... 모르겠어요ㅠㅠㅠㅠ <b>파이썬</b> 공식홈페이지에서 win7 지원하는 마지막 버전 링크드립니다. 64비트 컴퓨터... '},
#   {'title': '<b>파이썬</b> 버전',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=61303&docId=404144352&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=53&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 코딩을 시작 하려고 하는데요 유튜브와 책을 보면서 독학하려 하는데 책(기초)과 <b>파이썬</b> 설치 할때... 강좌라면 노마드 코더 (https://nomadcoders.co)의 무료 <b>파이썬</b> 웹 스크래퍼 강좌 봤고, 그 밖에는 인터넷 특히... '},
#   {'title': '<b>파이썬</b>, 웹사이트',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=396391526&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=54&search_sort=0&spq=0',
#    'description': '제가 <b>파이썬</b>을 배워볼까 하는데요. 웹사이트정도 만들려면 몇 년 걸리나요? 웹사이트를 만들고 싶다면 <b>파이썬</b>을... <b>파이썬</b>을 여쭤보셨으니, 이에 맞춰 답변드리자면, <b>파이썬</b>에서 Django라는 프레임워크가 있습니다. <b>파이썬</b>으로... '},
#   {'title': '<b>파이썬</b> (초보자) 질문 ㅠㅠ',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=401965254&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=55&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>을 혼자 해볼려고 하는데 아래 사진들 처럼 뜨면서 실행이 안됩니다. 어떻게 해야되나요??  visual studio... 일단 d.py <b>파이썬</b> 프로그램은 이상이 없고요. 실행한 것을 보니, 그 부분이 잘못된 것을 보니, <b>파이썬</b> 실행... '},
#   {'title': '<b>파이썬</b> 초급 코딩질문입니다.',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=405544740&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=56&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>을 이용해 간단하게 rpg 형식의 일부분을 구현하고 싶은데요. 몬스터 HP = 1000이고 <b>파이썬</b> 사용자한테 직접 수치를 입력받아서 몬스터 HP = 0 이 될때까지 계속 사용자로부터 특정 수치를 입력받고... '},
#   {'title': '<b>파이썬</b> 16진수',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=403489586&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=57&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 교재를 보는데 16진수 출력하는 서식문자는 %x이고 16진수의 경우 포맷팅에 사용하는 표현은 %h라고 나와있는데 둘이 서로 다른게 맞나요? %x가 맞아요 %h는 hour로 시간을 나타내기 위해... '},
#   {'title': '<b>파이썬</b>에서',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=393023715&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=58&search_sort=0&spq=0',
#    'description': "... <b>파이썬</b>으로 이렇게 출력되게 하려면 어떻게 해야하나요? 다음과... center(24, ' ') print(star) ※ 질문주신 내용 이외에도, <b>파이썬</b>과... 참고하시기 바랍니다 :D https://dinolabs.tistory.com/category/BLOG/<b>파이썬</b> 기초 "},
#   {'title': '<b>파이썬</b> 질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=402196373&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=59&search_sort=0&spq=0',
#    'description': "<b>파이썬</b>문제 질문드립니다 5.11 전번 문제를 알아야지 정확합니다만 나름 풀이 import random n1 = random.randint(11,99) n2 = random.randint(11,99) dap=n1-n2 idap=int(input(str(n1)+' - '+str(n2)+' = ')) if dap... "},
#   {'title': '<b>파이썬</b> 독학',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=401162725&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=60&search_sort=0&spq=0',
#    'description': '... 생겨 <b>파이썬</b>을 독학해보려 합니다. <b>파이썬</b>은 빅데이터에 유리하다고 들었습니다. 독학을 할 때, <b>파이썬</b>으로... 그리고, <b>파이썬</b>을 쓰는 가장 주된 이유가 무엇인가요? <b>파이썬</b>을 학습후 r언어와 하둡을 배우시는걸 추천드립니다. <b>파이썬</b>을... '},
#   {'title': '<b>파이썬</b> 문제좀 해결 부탁드립니다 ㅜㅜ',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=404474118&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=61&search_sort=0&spq=0',
#    'description': "... 1} <b>파이썬</b> 문제가 이렇게 되어있는데 코딩을 어떻게 해야할까요?? # - make_word_count() 함수를... 1} # <b>파이썬</b> 문제가 이렇게 되어있는데 코딩을 어떻게 해야할까요?? print(make_word_count('data.... "},
#   {'title': '정보처리기사 자격증, <b>파이썬</b> 공부',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=111&docId=404901022&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=62&search_sort=0&spq=0',
#    'description': '... 아니면 <b>파이썬</b> 공부를 먼저 해야할까요?  <b>파이썬</b>과 정보처리기사 중 고민을... ◐ IT 분야 자격증, 교육 과정 * IT베이직 : C언어, <b>파이썬</b>, 자바 프로그램 등... R과 <b>파이썬</b>을 기본으로하는 과정 * 정보보안 전문가 : 시스템과 네트워크... '},
#   {'title': '<b>파이썬</b> 리스트 중복되는 값',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=405634985&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=63&search_sort=0&spq=0',
#    'description': '15개의 값을 입력받고, 리스트에 저장 후, 중복되는 값을 제거한 리스트 출력하기 <b>파이썬</b> 코딩 짜주세요..ㅠ values = [] for _ in range(15): values.append(input()) values = list(set(values)) '},
#   {'title': '<b>파이썬</b> 저장하는 법',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=403436223&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=64&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 코드짠걸 저장하려면 어떻게 해야하나요?  idle 에디터에서 하신건가요? file-&gt;Save as 저장할 폴더지정하고(그냥 하시면 기본 위치에) 이름 지정하고 저장 버튼'},
#   {'title': '<b>파이썬</b> 질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=403742833&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=65&search_sort=0&spq=0',
#    'description': "<b>파이썬</b> 이거 어떻게 하나요..? import sys, os for i in (2,6): for j in range(1, 10): for k in range(i, i+4): print(&quot;{0}*{1}={2}&quot;.format(k,j,k*j),end='\\t') print() print() "},
#   {'title': '<b>파이썬</b>에 대해서 기초',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=402294105&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=66&search_sort=0&spq=0',
#    'description': '... 그리고 <b>파이썬</b>으로 1부터 200까지의 홀수의 합수 짝수의 합 수 어케 구하나요 쉽게 설명부탁드려요 ㅠㅠ... 그리고 <b>파이썬</b>으로 1부터 200까지의 홀수의 합수 짝수의 합 수 어케 구하나요 쉽게 설명부탁드려요 ㅠㅠ... '},
#   {'title': '<b>파이썬</b>언어',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=399994975&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=67&search_sort=0&spq=0',
#    'description': '... <b>파이썬</b> 언어에서 조건문에 사용되는 관계 연산자 중 ‘같지않다’ 를 쓰시오 2. <b>파이썬</b> 언어에서 조건문에 사용되는 관계 연가자 중 ‘같다’를 쓰시오 1. <b>파이썬</b> 언어에서... = 2. <b>파이썬</b> 언어에서 조건문에 사용되는 관계 연가자 중... '},
#   {'title': '<b>파이썬</b> 함수 질문이요',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=393727117&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=68&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>에 avg() 나 average() 이런 함수 없나요? <b>파이썬</b>에서 평균을 구하는 함수가 없습니다. 따라서 아래와... ※ 질문주신 내용 이외에도, <b>파이썬</b>과 관련하여... 바랍니다 :D https://dinolabs.tistory.com/category/BLOG/<b>파이썬</b> 기초 '},
#   {'title': '<b>파이썬</b> 질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=402819519&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=69&search_sort=0&spq=0',
#    'description': "... 점수는 실수나 문자가 입력되면 체크하여 다시 입력해야 한다.를 <b>파이썬</b>으로 어떻게 나타내나요? scores = {'과제':0,'중간':0,'기말':0} for i in scores.keys(): while True: d = input('성적 입력(' + i +') ') if d.isdigit... "},
#   {'title': '<b>파이썬</b>에서 폴더 삭제하려면?',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=393727382&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=70&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>에서 폴더를 삭제하려면 어떻게 해야하나요? rmdir() 함수와... 이외에도, <b>파이썬</b>과 관련하여 궁금한 것들이 있다면, 아래 제... 참고하시기 바랍니다 :D https://dinolabs.tistory.com/category/BLOG/<b>파이썬</b> 기초 '},
#   {'title': '<b>파이썬</b> pyinstaller 패키징',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=404066987&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=71&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 3.8.9 사용중이고 talib 모듈 <b>파이썬</b> 3.8용 버전으로 pip install 하여 .py 로는 실행이잘되는데 exe 패키징 하면 실행이 안되네요 pyinstaller 실행될때 사용되는 <b>파이썬</b> 버전때문인가요?... '},
#   {'title': '<b>파이썬</b>인강 괜찮은 사이트 추천해주세요.',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110409&docId=405649366&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=72&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>인강 괜찮은 사이트 추천해주세요. 아이가 배우려기... 설명해주는 <b>파이썬</b> 인강사이트 찾고있습니다. 괜찮은 학원있으면... 아예 <b>파이썬</b> 인강보다는 기초통합과정인강을 들어보시는 것도 추천드리고 있습니다. 아래는 <b>파이썬</b>이... '},
#   {'title': '<b>파이썬</b> idle 코드',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=399682992&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=73&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> idle를 처음하는데 코드를 입력하고 엔터를 누른뒤에 확인해보니 코드가 틀렸는데 그럼 코드를 어떻게... <b>파이썬</b>의 idle는 두 가지 모드가 있습니다. 1. 다이렉트 모드 또는 직접 모드라고 하여 한줄씩 코드를 작성하여... '},
#   {'title': '프로그래밍 좀 배워보려고 하는데 자바와 <b>파이썬</b> 중... ',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=392241613&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=74&search_sort=0&spq=0',
#    'description': '프로그래밍 좀 배워보려고 하는데 자바와 <b>파이썬</b> 중 어느것... 자바와 <b>파이썬</b> 중 먼저 배울 프로그래밍 언어를 고민하고 계시군요. 둘 다 배우실 생각이시라면 <b>파이썬</b>부터... 둘다 쓰임새가 다양하고 요즘 인기 있는 언어인데 <b>파이썬</b>... '},
#   {'title': '<b>파이썬</b>독학 하려는데..',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=399028919&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=75&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>독학 하려고 하는데요... 내용이 쉽지는 않겠지만 그래도... 요새 <b>파이썬</b>독학에 도움이 될만한 인강사이트는 어디일까요? <b>파이썬</b>독학 하려고 하시나봐요! 여러가지 다양한 인강사이트에서 <b>파이썬</b>독학에 도움이 되실만한 인강을... '},
#   {'title': '<b>파이썬</b> 코딩...',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=401295145&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=76&search_sort=0&spq=0',
#    'description': '제가 이제 <b>파이썬</b> 입문 했는데요.. txt파일에 들어가 맨 앞자리 숫자를 바꾸는 프로그램짤려는데 어케... 고수님들 알려주세요 ㅠㅠ 내공 100검 # 제가 이제 <b>파이썬</b> 입문 했는데요.. txt파일에 들어가 맨... '},
#   {'title': '<b>파이썬</b> 질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=403355134&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=77&search_sort=0&spq=0',
#    'description': '중간값을 도출하는 <b>파이썬</b>에서 문자를 작은 순서대로 나열한 것은 알겠는데 그 다음을 어떻게 해야할지 모르겠네영.. 구하시는 중간 값이 list의 중간에 있는 값이라면 아래와 같이 구하실 수 있습니다.... '},
#   {'title': '<b>파이썬</b> 리스트형 중',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=402250500&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=78&search_sort=0&spq=0',
#    'description': '... <b>파이썬</b> 초보입니다. c=[[1,2],[20,30]] 이라 할 때 c[0][1]+=c[1][1] print(c)을 입력 시 [[1,32],[20,30]] 가... <b>파이썬</b>에 입력 시 32가 나오는데 왜 32인지 모르겠습니다. 2. 저 식에서 += 는 대체 뭐죠? 3. 대체 왜 print(c)가 [[1... '},
#   {'title': '<b>파이썬</b> 조건문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=405818395&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=79&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>으로 도형 그리기에서 if 조건문이랑 whlie 써서 저런식으로 프로그램 했는데 왜 오각형만 그려질까요?? 알고리즘 어떻게 짜야 하나요??  박스안에서 무한 반복을 하게 됩니다. 그래서 pentagon() 만 실행이 되고요. 그래서... '},
#   {'title': '<b>파이썬</b> 변수에 특수문자',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=403407909&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=80&search_sort=0&spq=0',
#    'description': "<b>파이썬</b> 변수에 특수문자 지정을 하고 싶으면 어떻게 하나요? 밑처럼 했을 때 ! ! @ * # @ 이렇게 출력되었으면 좋겠어요 for i in '!!@*#@': A = i print(A)  #<b>파이썬</b> #python for c in '!!@*#@': print(c) A나 i 둘 다... "},
#   {'title': '<b>파이썬</b> 리스트 질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=400589711&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=81&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 리스트가 예를 들어서 A = [1,2,3,4]이면 0번째가 1로 출력되잖아요? 근데 리스트를 사용하되, 1번째가 1로... <b>파이썬</b> 문법의 근간을 흔드는 일이 되겠네요. 임의적으로 index 0 에 쓰레기값을 넣어서 질문자만 알아서 사용해야... '},
#   {'title': '<b>파이썬</b> for 문 반복문 (버전 2.7)',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=404087168&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=82&search_sort=0&spq=0',
#    'description': "<b>파이썬</b> for 문을 이용해서 * *** ***** *** * 이렇게 나오게 어떻게 만드나요? s = 2 x = 1 for i in range (1, 6) : print(' ' * s, end = '') print('*' * x) if i &gt;= 3 : s += 1 x -= 2 else : s -= 1 x += 2 "},
#   {'title': '<b>파이썬</b> 문제 질문드립니다',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=102020101&docId=401299591&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=83&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 문제 질문드립니다 ㅠㅠ 1:1 질문 답변드립니다. n = int(input(&quot;: &quot;)) if n &gt;=0 and n &lt;=100 and n % 2 == 0 : print(True) else: print(False) '},
#   {'title': '<b>파이썬</b> 문제 도와주세요 ..',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=401218388&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=84&search_sort=0&spq=0',
#    'description': "<b>파이썬</b> 문제인데 모르겠어요 while True: n = input('이진수 입력 ') sum = 0 c = 0 for idx,d in enumerate(n): if d != '1' and d != '0': print('잘못된 이진수 다시 입력') c = 1 break if d == '1': sum += 2 ** ( len(n)... "},
#   {'title': '<b>파이썬</b> gui',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=401797106&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=85&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>을 이제 막 배우고 있는데요.. gui는 화면을 만드는 거라고 알고있는데.... 굳이, <b>파이썬</b>으로 만드는 이유가 있나요? <b>파이썬</b>이란 언어는 보이는 모양... <b>파이썬</b>으로 GUI를 만드는 건 화려하고 멋진 무언가를 만들기 위함이 아닌... '},
#   {'title': '<b>파이썬</b> 프로그래밍',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=402731786&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=86&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 프로그래밍 문제인데 도저히 모르겠어서 올립니다ㅠ 아래 문제 해결해주실 수 있나요?... 테스트 후 루프 구조를 사용하여 <b>파이썬</b> 프로그램을 작성하여 모집단이 2만 명 미만이 되려면 몇 년이 걸릴지... '},
#   {'title': '<b>파이썬</b> 백신접종 프로그래밍',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=403166213&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=87&search_sort=0&spq=0',
#    'description': "위 사진애 나오는 프로그래밍 코드좀 짜주세요 <b>파이썬</b>이고 반복중첩문사용해주세요 age = int(input('만 나이 입력 : ')) year = int(input('출생연도 끝자리 입력 : ')) day =['금요일','월요일','화요일','수요일... "},
#   {'title': '<b>파이썬</b> 자주쓰는 라이브러리 소개부탁드립니다.',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=402724417&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=88&search_sort=0&spq=0',
#    'description': '안녕하세요 <b>파이썬</b>을 처음 시작하는 유저입니다. <b>파이썬</b>에서 대표적으로 쓰는 라이브러리들은 무엇이 있는지... 코드를 개선해나가면서 이것저것 패키지를 많이 깔아야 될텐데 일반적으로 <b>파이썬</b> 쓰시면서 많이 쓰는 것들은... '},
#   {'title': '<b>파이썬</b> 별 마름모 출력',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=402638634&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=89&search_sort=0&spq=0',
#    'description': "<b>파이썬</b> 현재 반복문까지 배웠습니다., 이 프로그램 짜는 방법이 너무 궁금합니다.. 되도록 간결하고 짧게 짜주시도록 부탁드립니다.ㅠ for i in range(5): print(&quot; &quot;*(5-i),end='') print(&quot;*&quot;*(i*2+1)) for i in range(4)... "},
#   {'title': '<b>파이썬</b> 독학 어떻게 해요?',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=404214464&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=90&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 독학 어떻게 해요?  <b>파이썬</b>이 쉽게 접할 수 있다고는 하나, 프로그래밍언어에 대한 기초적인 지식과 이해가... 이해가 어렵다면, 학원을 통해 도움을 받으셔야 할것 같습니다. &gt;&gt; 프로그래밍과정 문의 <b>파이썬</b>/자바/C언어 알아보기'},
#   {'title': '<b>파이썬</b>학원추천 좀 해주세요',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10406&docId=402979608&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=91&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>학원추천 좀 해주세요 올해 고3이고 수험이 끝나서... 때 <b>파이썬</b> 배워두고 가면 좋다고 해서 배워볼 까 생각중입니다. 혹시, 서울 주변에 <b>파이썬</b> 학원으로 가장 괜찮은... <b>파이썬</b> 과정이 필요하셔서 공부를 희망하신다고 말씀해... '},
#   {'title': '<b>파이썬</b> 코딩언어(?)',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1040101&docId=345428236&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=92&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 코딩언어(?) Input() 이나 int()등 기초적으로 사용되는것들있잖아요... 지금 <b>파이썬</b> 공부하려는데 저런 기초적인단어가 무슨뜻인지 몰라서 자꾸... <b>파이썬</b> 공부 하실 수 있는 인강 사이트 알려드리겠습니다. 참고해보세요. 현재... '},
#   {'title': '<b>파이썬</b> 코드 질문이욥',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=393652588&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=93&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 코드 질문드립니다. 문자열에서 공백 기준으로 문자를 다... 이외에도, <b>파이썬</b>과 관련하여 궁금한 것들이 있다면, 아래 제 블로그에... 글을 참고하시기 바랍니다 :D https://dinolabs.tistory.com/category/BLOG/<b>파이썬</b> 기초 '},
#   {'title': '클라우드엔지니어, <b>파이썬</b>',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=401119087&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=94&search_sort=0&spq=0',
#    'description': '클라우드 엔지니어에게 <b>파이썬</b> 코딩능력이 요구되기도 한다는데 <b>파이썬</b>의 자동화, 웹크롤러 관련되서 나오는 이야기... 클라우드 기술과 <b>파이썬</b>이 구체적으로 어떤 연관을 갖고 있는지 알고싶습니다. 실제로 클라우드기술자가 <b>파이썬</b>을... '},
#   {'title': '<b>파이썬</b> 질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=401649255&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=95&search_sort=0&spq=0',
#    'description': "<b>파이썬</b> 두문제 질문입니다 ㅠㅠ! d = input('입력 :') if d.lower() in ['a','e','i','o','u']: print(f'{d} (은)는 모음입니다.') else: print(f'{d} (은)는 자음입니다.') a,b,c = map(int,input('세... "},
#   {'title': '<b>파이썬</b> 프로그램 짜기',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=406413458&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=96&search_sort=0&spq=0',
#    'description': '<b>파이썬</b> 프로그램 짜기가 수행인데 (for문,if문 등등등 다 사욯해서 ) 어떻게 해야될지 감이 안잡혀요 ㅠㅠㅜㅜㅜ 도와주세요 엄청 쉽고 초등수준이여도 괜찮아요 ㅈㅂㅈㅂ  user = {} while True: choice... '},
#   {'title': '<b>파이썬</b>강의 볼 수 있는 곳 소개해주세요',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=111&docId=406277468&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=97&search_sort=0&spq=0',
#    'description': '기초 설명 잘 해주는 <b>파이썬</b>강의 찾고 있어요. 가격... 계획이라 <b>파이썬</b>강의 외에 C언어강의도 수강할 수 있는 곳이면 좋겠습니다.  기초 설명 잘 해주는 <b>파이썬</b>강의 찾고... 그리고 추후 C언어도 공부할 계획이라 <b>파이썬</b>강의 외에... '},
#   {'title': '<b>파이썬</b> 설정질문',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=405143981&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=98&search_sort=0&spq=0',
#    'description': '<b>파이썬</b>을 처음으로 배워보려고 유튜브를 따라하고 있는데 계속해서 디버그 실행하면 저렇게 나오고 연산결과가 안나와요.... 어떻게 해야할까요? 아래 명령창에 ps : c:￦ ....&gt; 상태 일때 수행하세요 아래가 python프롬프트... '},
#   {'title': '<b>파이썬</b> true 질문이요',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10402&docId=393495808&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=99&search_sort=0&spq=0',
#    'description': "<b>파이썬</b>에서 'True' 라고 반환된 값은 문자열 데이터인가요? True', 또는... ※ 질문주신 내용 이외에도, <b>파이썬</b>과 관련하여 궁금한 것들이 있다면... 참고하시기 바랍니다 :D https://dinolabs.tistory.com/category/BLOG/<b>파이썬</b> 기초 "},
#   {'title': '<b>파이썬</b>프로그래밍 배울 수 있는 학원 알려주세요.',
#    'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=399678119&qb=7YyM7J207I2s&enc=utf8&section=kin.qna&rank=100&search_sort=0&spq=0',
#    'description': '... 2학기부터 <b>파이썬</b>프로그래밍 수업을 공부한다고 하는데 학원에가서 전문적으로 배울 수 있는 <b>파이썬</b>프로그래밍... <b>파이썬</b>프로그래밍 수업이 필요하셔서 교육기관을을... ㆍ프로그래밍언어 ( <b>파이썬</b> , C언어 , C++ ) ㆍ운영체제... '}]}

# %%
one_result['items'][0]['description']
# Out:
# '<b>파이썬</b>은 백준 기준으로 브론즈는 웬만큼 풀 줄 알게 되었고... <b>파이썬</b> 공부는 앞으로 어떻게 해나가면 좋을지 잘 모르겠습니다. 아직은 <b>파이썬</b> 초보라고 생각하기에 초보에게... <b>파이썬</b>과 C언어를 공부하고 계신데요. 기본적으로... '

# %%
def delete_tag(input_str):
    input_str = input_str.replace('<b>', '')
    input_str = input_str.replace('</b>', '')
    return input_str

# %%
def get_description(pages):
    contents = []
    
    for sentences in pages['items']:
        contents.append(delete_tag(sentences['description']))
        
    return contents

# %%
contents = get_description(one_result)
contents
# Out:
# ['파이썬은 백준 기준으로 브론즈는 웬만큼 풀 줄 알게 되었고... 파이썬 공부는 앞으로 어떻게 해나가면 좋을지 잘 모르겠습니다. 아직은 파이썬 초보라고 생각하기에 초보에게... 파이썬과 C언어를 공부하고 계신데요. 기본적으로... ',
#  "파이썬 문제 해결  import turtle print('이 프로그램은 다각형') d = 100 while True: n = input('원하는 다각형(3,4,5 종료:x) ') x,y = map(int,input('위치 x,y ').split(',')) turtle.penup() turtle.... ",
#  '파이썬 코딩 이거 어떻게 하는지 알려주세요 ㅠㅜ 내공 50이요!! def Pyung2msq(value): return value * 3.3 def Msq2pyung(value): return value / 3.3 def Cm2inch(value): return value * 0.394 def Inch2cm(value)... ',
#  "저기 밑에 SELF STUDY 부분 파이썬 코딩 이거 어떻게 하는지 알려주세요 ㅠㅜ 내공 100이요 !!! ss = '파이썬은완전재미있어요' sslen = len(ss) for i in range(0 , sslen) : if i % 2 == 0 : print(ss[i], end='') else... ",
#  '파이썬 for, while문 연습문제로 나와있는 건데요 위 그림 순서대로 (1),(2),(3),(4) 차례로... D:\\파이썬코드\\test... ',
#  "파이썬 문제의 답 알려주세요%%  이렇게인 듯? import time now = time.time() sum = 0 for i in range(10000000): sum += 1 passed_time = time.time() - now print(f'계산 소요 시간: {passed_time:.5f}초')",
#  '파이썬에서 &amp;은 뭔가요? &amp;는 bitwise AND라고 해서 2진수숫자들끼리 각 자릿수를 AND를 하는겁니다. 예로 들어 a = 14 b = 4 print(b &amp; a) # 4를 출력. 0000 1110 (14) &amp; 0000 0100 (4) = 0000 0100 ',
#  '마인크래프트 파이썬을 배워보고 싶은데 배울 곳 없나요? 그리고 그걸 적용하는 방법과 앱까지 알 수 있는 곳... 답변: be는 파이썬과 관련 없으므로 php 를 배워야 합니다. 구글에서 php 를 검색하고 유튜브 강좌를 이용하세요.... ',
#  '버튼을 이용하여 count up, count down, 파이썬 종료하는 윈도우... text=&quot;파이썬 종료&quot;,fg=&quot;red&quot;,command = quit) button2 = Button(window... config(text=str(number)) button1 = Button(window, text=&quot;파이썬 종료... ',
#  "... 로 출력되게 파이썬에서 코딩하려면 어떻게 해야하나요ㅜㅠ? 질문의 정확한 의도를 잘 모르지만........ def f(n) : A=2*(n-1)-1 print(f'A는 {A}입니다.') f(10) ====================== RESTART: D:\\python39\\1.py... ",
#  '파이썬으로 만들 수 있는 짧으면서 간단한 인공지능 알려주세요. &quot;짧으면서 간단&quot;한 이라는 게 사람마다... 파이썬 Python Macro 구현 pyautogui 이미지 인식하여 마우스 컨트롤 하는 법 + opencv-python (tistory.com) 만들어진... ',
#  '파이썬 구동을 위해 갖추어야 할 노트북 환경은 어떻게 되나요? 노트북을 구매할 때 고려해야 할 사항이 무엇인지... 파이썬을 배우고 있는 중이라면 당장은 그렇게 좋은 사양의 노트북은 필요 없습니다. 하지만 실력이 좋아지고 다른... ',
#  '... 파이썬라이버러리는 어디서 다운받을수가 있나요 라이브러리라는 뜻은 특정 기능을 만들어서 공통으로 다른... 일반적으로 파이썬의 라이브러리는 pip 이라는 명령으로 설치를 하는데요. (이른바 공인된 라이브러리) 수학적인... ',
#  '파이썬인강이 필요해서 알아보고 있었는데요. 오프라인... 파이썬를 인강으로 배울 수 있게끔 잘 구성되어... 파이썬인강으로 쫌 유명한 홈페이지나, 학원이 있다면... 파이썬인강을 알아보고 계신다면 딱 좋은 학원강의가 있어서... ',
#  "사랑의 방정식을 파이썬으로 돌릴 수는 없나요? 함수 축이 나오는 것까진 했는데... axis('equal') plt.plot(x, y) plt.title('fifth heart curve | parametric equations') plt.show() #파이썬 #python ",
#  '... 파이썬으로 가능한가요? 안되면 무슨 언어로 하는 게 가장 편한가요? 파이썬으로 pystray 모듈을 사용하여 간편하게 만들수 있습니다. 아래 코드 실행해보세요. 더 많은 것이 궁금하시면... ',
#  "파이썬에서 텍스트에 특정 단어 여부를 알아내는 알고리즘을 만들고 싶은데 단어가 한글일 때 어떻게 해야 할까요..? s = 'show me the money' a = 'me' b = 'THE' if a in s : print('있음') else : print('없음') if b in... ",
#  '파이썬 vscode로 독학해서 배우고 잇는데 파이썬 코드 실행이 안됩니다. 실행 버튼이 있긴한데 다른 영상들과... 전문가분들 도와주세요 ㅜㅜ  처음 파이썬 하시는 것이라면 vscode에서 하시는 것보다는 IDLE에서 하세요. 파이썬을... ',
#  '몇년전에 파이썬이 제일 쉽다고 들은 것 같은데 요즘도 그러나요?  코딩을 처음 접하는 초보자분들이 파이썬으로 코딩공부를 가장 많이 시작하십니다. https://blog.naver.com/95shinha/222490214649',
#  '... 파이썬 입문자 입니다 연습문제로 풀어보려고 하는게 너무 어려워서 한번 여쭤봅니다. 조건은... argv[1:] main(args) 실행 이런 형태로 입력하는데 저의 파이썬 파일은 k_23.py였어요. 작성자님은 알맞게... ',
#  '[퀴즈1,퀴즈2, 퀴즈3] 이렇게 해서 코드를 짠다음에 퀴즈1를 고르면 그 퀴즈가 나오는 그런 코드는 파이썬에서는 못짜나요?? 짤수 있다면 알려주실 수 있을까요? 제가 가진 내공을 다 걸께요ㅜㅠ 파이썬에서 지원하는 데이터... ',
#  '... 파이썬 관련 한가지 질문을 드립니다. 제가 Jupiter Notebook을 사용하고 있습니다. 그리고 저한테... 제가 아직 파이썬을 공부한지 얼마 안된 초보자라 잘 모르겠습니다. 어떤 식으로 해야하는지... ',
#  '파이썬 공부를 먼저 해야할까요 아니면 자격증 공부하고 파이썬으로 넘어가는게 좋을까요? 응시자격조건은... 파이썬 책과 파이썬 인강 병행해서 공부하시는 걸 추천드립니다. 궁금한 점은 블로그 통해 글 남겨주세요.',
#  '파이썬을 이용한 인공지능이 있을까요? 파이썬으로 어떤 인공지능을 만들 수 있나요? 파이썬(코딩)도... 안녕하세요, 메가 IT 진로담당컨설턴트 신짱입니다~~ 인공지능 기술의 기반이 되는 프로그래밍언어가 파이썬입니다... ',
#  "임의의 숫자를 입력받아서 그 숫자들의 합계와 각 숫자들의 비율을 나타내는 파이썬 구현할 수 있을까요? ex) 입력받은 시간이 1,2,3 이라면 합계 = 6 a = 17 b = 33 c = 50 a = int(input('수1을 입력하세요 : ')) b... ",
#  '파이썬에서 enumerate는 언제 사용하나요? enumerate() 함수는 주로... (5,300) ※ 질문주신 내용 이외에도, 파이썬과 관련하여 궁금한... 참고하시기 바랍니다 :D https://dinolabs.tistory.com/category/BLOG/파이썬 기초 ',
#  '파이썬독학 해도 괜찮을까요? 제가 파이썬독학을 해볼까 했는데 좀 힘든거 같아서 독학 안하고 도움을 받을곳에서... 배워야 파이썬독학 할때보다 더 좋을까요? 파이썬독학 하는것보다는 배우는게 더 도움이 될거 같은데 혼자 독학하다가... ',
#  '파이썬을 잘몰라서 질문합니다. 파이썬으로 작성한 코드를 열람이나... 안녕하세요 파이썬으로 작성한 프로그램을 다른 사람들이 해당 프로그램의... pyinstaller는 파이썬 프로그램을 exe파일로 변환을 해 주는 모듈이기 때문에... ',
#  '... 파이썬 세계로 오신걸 환영합니다. 파이썬은 비단뱀 처럼 매력적인 언어입니다.&quot;&quot;&quot; cnt=0... 파이썬 세계로 오신걸 환영합니다. 파이썬은 비단뱀 처럼 매력적인 언어입니다.&quot;&quot;&quot; cnt = 0... ',
#  '... 파이썬의 속도는 c, java에 비교하면 어느정돈가요? 파이썬의 속도를 1이라 가정했을때 c, java의 수치는? 2. 파이썬은 1초에 연산을 몇번하나요? 1. https... 파이썬은 c에 비해서 71.90 배 느린 속도로 연산을 합니다. 저... ',
#  '파이썬으로 def 함수 하고 있는데 사진처럼 계속 오류가 나요 왜 그런건가요?? 계속 IDLE에서만 하다가 파이썬으로 직접하는데 이러내요 IDLE에서는 오류가 안 나는데 파이썬으로만 하면 오류가... ',
#  "이거 파이썬 어떻게 작성하나요ㅜㅜ from turtle import * import math r = int(input('반지름 ')) while True: d = int(input('도형 ')) if d &gt;= 3 and d &lt;=6: break x = int(input('원 둘레 ')) if x : circle... ",
#  '파이썬 임의의 난수 질문드립니다! https://kin.naver.com/qna/detail.nhn?d1id=1&amp;dirId=1040201&amp;docId=401830375&amp;page=1#answer1 제가 답변하여 채택된 글입니다. 동일한 문제집 같습니다. ',
#  '... 혹시 파이썬도 위와 같이 창업을 할 수 있는 방법(?)이 뭐가... 또한 웹이나 앱은 1인 개발이 가능한데 파이썬으로 1인 개발로... 파이썬을 활용한 1인 창업을 고민하고 계신데요. 파이썬도 Django 프레임워크를 활용하면 웹 개발을 할 수... ',
#  '메모장에 파이썬에서 실행해야할 명령을 적어놓고 저장해놓았다가 파이썬에 이를 가져와서 실행하고 싶은데 어떻게 해야하나요? 질문 내용을 보아 파이썬 코딩을 메모장에서 할 수 있느냐는 질문으로 보입니다. 메모장에서 아래와... ',
#  '제가 파이썬을 공부하고 있는데 파이썬 파일과 같은 위치에 &quot;a.txt&quot;라는 파일을 만들고 싶어요. 근데 만약 이미 있으면 만들 필요가 없어서 실행시키지 않고 싶은데 이걸 어떻게 할까요? if문을 쓰면... ',
#  '파이썬 질문드려요 ㅠㅠㅠ 길이 단위 변환하는 프로그램을 파이썬으로 하고 있는데 출력을 하려고 하면 자꾸 dongDic이 정의되지 않았다고 오류가 나오네요,,, ㅠㅠㅠㅠ 어떤 부분이 오류인가요... DongUnit 함수에는 mm를... ',
#  '파이썬 도형 그리기 각도 계산하는 법 알려주세요 삼각형/사각형/오각형 부탁드립니다. turtle.circle(&lt;반지름 길이&gt;,360,&lt;꼭짓점 개수&gt;) 위와 같이 입력하면 정다각형을 그립니다. #파이썬 #python ',
#  '파이썬에서 += 를 어떻게 읽나요?  전제이름은 복합연산자, 복합 대입 연산자 입니다 세부 이름은 모르겠네요. 자신에 더하기 하기?',
#  '아직 제가 파이썬에 대해 잘 몰라서 어디가 틀린지... 파이썬을 이제 막 대학교에서 처음 배우고 있는데 숙제를... 시험도 이제 한 달 밖에 안 남았는데 파이썬은 벼락치기... 파이썬 자체는 어려운 프로그래밍 언어는 아닙니다. 다만... ',
#  '학교 정보 수행이 파이썬으로 뭐를 만들어 오라고 하셨는데 하나도 모르겠어서...파이썬 리스트로 간단한 예문 하나만 만들어 주심 감사하겠습니다.내공 50 걸게요. 가능한 빨리 부탁드립니다.  import... ',
#  "파이썬 홐자서 공부하는중인데 4-22, 23을 못풀겠습니다 도와주세요 # 4.22 import datetime date = datetime.datetime.now() y, m, d = date.year, date.month, date.day print(f'현재 시간은 {y}년 {m}월 {d}... ",
#  '; 를 파이썬에서 왜 사용하는지 역할이 뭔지 알려주세요 보통 프로그래밍 언어에서 세미콜론의 역할은 그 문장의 종료를 나타냅니다. 파이썬같은 경우는 굳이 안써도 되지만... 그냥 실수로 쓴 것 같아 보입니다. ',
#  '파이썬 공부 중입니다. 파이썬은 원래 오타 한번 나서 오류 나면 첨부터 다시 써야 되나요?? 씨플플이나 자바는... IDLE같은 파이썬 셸에서 하기 때문입니다. IDLE같은 경우에는 셸에서 하지마세요. 셸은 아래의 사진같은 화면입니다.... ',
#  '... 파이썬으로 데이터 분석 등을 할 수 있다고도 하고 반복작업을 할 수 있다고 하는데 혹시 엑셀파일로 정리된... 것도 파이썬으로 자동 등록 할 수 있는건가요? 웹스크래핑, 크롤링으로 가능한 내용입니다. 데이터 분석도 pandas 를... ',
#  '파이썬 실습인데 특수문자를 어떻게 공백으로 바꾸어요?ㅜㅜ  음 이런걸 말하는건가요? sp = &quot;~!@#$%^&amp;*-_+=(){}:;?.,&lt;&gt;&quot; inputStr = input() outputStr = &quot;&quot; for s in inputStr: if s in sp: outputStr += &quot; &quot; else... ',
#  '사진에 있는 파이썬 코딩 최대한 자세하게 설명부탁드려요 가장 이해가 안 되는 부분은 import 아래의 l=[ ] 이 부분이 어떻게 쓰여지는 건지 모르겠어요 나머지 부분도 설명부탁드립니다!! # 랜덤 모듈 생성 import... ',
#  "파이썬으로 * ** *** **** ***** ****** ******* 이거 코딩 어떻게 해야 하나요? for랑 while 둘 다 알려주세요ㅠㅠㅠㅠㅠ  for i in range(7): print(' '*(6-i),end='') print('* '*(i+1))",
#  "... 도와주세요 ㅜㅜ 파이썬 잘하시는 분들 제발... score = int(input('기초파이썬 예상 점수 : ')) if score &gt;= 95: print('당신의 기초파이썬 학점은 A+ 입니다.') elif score &gt;= 90: print('당신의 기초파이썬 학점은 A... ",
#  '파이썬 공부를 하는데 계속 오류가 뜨더라구요. avg안에 들어갈 값하고 7번째 줄에서 계속 오류가... 98이 나와야 하는데 에러만 뜨네요… raise 는 파이썬에서 예외를 발생시키기 위한 키워드 입니다.... ',
#  '... 최근 파이썬 언어에 관심이 생겨 학습중인 학생입니다. 최근... 저는 파이썬을 무료로 받아서 사용하고 있는데 이것은... 제가 만약 무료인 파이썬을 사용해서 모듈이나 소프트웨어를 제작한다면, 제가 제작한 제작물은 파이썬... ',
#  '파이썬 설치를 하려고 하는데 최신 버전은 10이상만 된다고 하네요..윈도우7에 파이썬 설치하려면 전... 모르겠어요ㅠㅠㅠㅠ 파이썬 공식홈페이지에서 win7 지원하는 마지막 버전 링크드립니다. 64비트 컴퓨터... ',
#  '파이썬 코딩을 시작 하려고 하는데요 유튜브와 책을 보면서 독학하려 하는데 책(기초)과 파이썬 설치 할때... 강좌라면 노마드 코더 (https://nomadcoders.co)의 무료 파이썬 웹 스크래퍼 강좌 봤고, 그 밖에는 인터넷 특히... ',
#  '제가 파이썬을 배워볼까 하는데요. 웹사이트정도 만들려면 몇 년 걸리나요? 웹사이트를 만들고 싶다면 파이썬을... 파이썬을 여쭤보셨으니, 이에 맞춰 답변드리자면, 파이썬에서 Django라는 프레임워크가 있습니다. 파이썬으로... ',
#  '파이썬을 혼자 해볼려고 하는데 아래 사진들 처럼 뜨면서 실행이 안됩니다. 어떻게 해야되나요??  visual studio... 일단 d.py 파이썬 프로그램은 이상이 없고요. 실행한 것을 보니, 그 부분이 잘못된 것을 보니, 파이썬 실행... ',
#  '파이썬을 이용해 간단하게 rpg 형식의 일부분을 구현하고 싶은데요. 몬스터 HP = 1000이고 파이썬 사용자한테 직접 수치를 입력받아서 몬스터 HP = 0 이 될때까지 계속 사용자로부터 특정 수치를 입력받고... ',
#  '파이썬 교재를 보는데 16진수 출력하는 서식문자는 %x이고 16진수의 경우 포맷팅에 사용하는 표현은 %h라고 나와있는데 둘이 서로 다른게 맞나요? %x가 맞아요 %h는 hour로 시간을 나타내기 위해... ',
#  "... 파이썬으로 이렇게 출력되게 하려면 어떻게 해야하나요? 다음과... center(24, ' ') print(star) ※ 질문주신 내용 이외에도, 파이썬과... 참고하시기 바랍니다 :D https://dinolabs.tistory.com/category/BLOG/파이썬 기초 ",
#  "파이썬문제 질문드립니다 5.11 전번 문제를 알아야지 정확합니다만 나름 풀이 import random n1 = random.randint(11,99) n2 = random.randint(11,99) dap=n1-n2 idap=int(input(str(n1)+' - '+str(n2)+' = ')) if dap... ",
#  '... 생겨 파이썬을 독학해보려 합니다. 파이썬은 빅데이터에 유리하다고 들었습니다. 독학을 할 때, 파이썬으로... 그리고, 파이썬을 쓰는 가장 주된 이유가 무엇인가요? 파이썬을 학습후 r언어와 하둡을 배우시는걸 추천드립니다. 파이썬을... ',
#  "... 1} 파이썬 문제가 이렇게 되어있는데 코딩을 어떻게 해야할까요?? # - make_word_count() 함수를... 1} # 파이썬 문제가 이렇게 되어있는데 코딩을 어떻게 해야할까요?? print(make_word_count('data.... ",
#  '... 아니면 파이썬 공부를 먼저 해야할까요?  파이썬과 정보처리기사 중 고민을... ◐ IT 분야 자격증, 교육 과정 * IT베이직 : C언어, 파이썬, 자바 프로그램 등... R과 파이썬을 기본으로하는 과정 * 정보보안 전문가 : 시스템과 네트워크... ',
#  '15개의 값을 입력받고, 리스트에 저장 후, 중복되는 값을 제거한 리스트 출력하기 파이썬 코딩 짜주세요..ㅠ values = [] for _ in range(15): values.append(input()) values = list(set(values)) ',
#  '파이썬 코드짠걸 저장하려면 어떻게 해야하나요?  idle 에디터에서 하신건가요? file-&gt;Save as 저장할 폴더지정하고(그냥 하시면 기본 위치에) 이름 지정하고 저장 버튼',
#  "파이썬 이거 어떻게 하나요..? import sys, os for i in (2,6): for j in range(1, 10): for k in range(i, i+4): print(&quot;{0}*{1}={2}&quot;.format(k,j,k*j),end='\\t') print() print() ",
#  '... 그리고 파이썬으로 1부터 200까지의 홀수의 합수 짝수의 합 수 어케 구하나요 쉽게 설명부탁드려요 ㅠㅠ... 그리고 파이썬으로 1부터 200까지의 홀수의 합수 짝수의 합 수 어케 구하나요 쉽게 설명부탁드려요 ㅠㅠ... ',
#  '... 파이썬 언어에서 조건문에 사용되는 관계 연산자 중 ‘같지않다’ 를 쓰시오 2. 파이썬 언어에서 조건문에 사용되는 관계 연가자 중 ‘같다’를 쓰시오 1. 파이썬 언어에서... = 2. 파이썬 언어에서 조건문에 사용되는 관계 연가자 중... ',
#  '파이썬에 avg() 나 average() 이런 함수 없나요? 파이썬에서 평균을 구하는 함수가 없습니다. 따라서 아래와... ※ 질문주신 내용 이외에도, 파이썬과 관련하여... 바랍니다 :D https://dinolabs.tistory.com/category/BLOG/파이썬 기초 ',
#  "... 점수는 실수나 문자가 입력되면 체크하여 다시 입력해야 한다.를 파이썬으로 어떻게 나타내나요? scores = {'과제':0,'중간':0,'기말':0} for i in scores.keys(): while True: d = input('성적 입력(' + i +') ') if d.isdigit... ",
#  '파이썬에서 폴더를 삭제하려면 어떻게 해야하나요? rmdir() 함수와... 이외에도, 파이썬과 관련하여 궁금한 것들이 있다면, 아래 제... 참고하시기 바랍니다 :D https://dinolabs.tistory.com/category/BLOG/파이썬 기초 ',
#  '파이썬 3.8.9 사용중이고 talib 모듈 파이썬 3.8용 버전으로 pip install 하여 .py 로는 실행이잘되는데 exe 패키징 하면 실행이 안되네요 pyinstaller 실행될때 사용되는 파이썬 버전때문인가요?... ',
#  '파이썬인강 괜찮은 사이트 추천해주세요. 아이가 배우려기... 설명해주는 파이썬 인강사이트 찾고있습니다. 괜찮은 학원있으면... 아예 파이썬 인강보다는 기초통합과정인강을 들어보시는 것도 추천드리고 있습니다. 아래는 파이썬이... ',
#  '파이썬 idle를 처음하는데 코드를 입력하고 엔터를 누른뒤에 확인해보니 코드가 틀렸는데 그럼 코드를 어떻게... 파이썬의 idle는 두 가지 모드가 있습니다. 1. 다이렉트 모드 또는 직접 모드라고 하여 한줄씩 코드를 작성하여... ',
#  '프로그래밍 좀 배워보려고 하는데 자바와 파이썬 중 어느것... 자바와 파이썬 중 먼저 배울 프로그래밍 언어를 고민하고 계시군요. 둘 다 배우실 생각이시라면 파이썬부터... 둘다 쓰임새가 다양하고 요즘 인기 있는 언어인데 파이썬... ',
#  '파이썬독학 하려고 하는데요... 내용이 쉽지는 않겠지만 그래도... 요새 파이썬독학에 도움이 될만한 인강사이트는 어디일까요? 파이썬독학 하려고 하시나봐요! 여러가지 다양한 인강사이트에서 파이썬독학에 도움이 되실만한 인강을... ',
#  '제가 이제 파이썬 입문 했는데요.. txt파일에 들어가 맨 앞자리 숫자를 바꾸는 프로그램짤려는데 어케... 고수님들 알려주세요 ㅠㅠ 내공 100검 # 제가 이제 파이썬 입문 했는데요.. txt파일에 들어가 맨... ',
#  '중간값을 도출하는 파이썬에서 문자를 작은 순서대로 나열한 것은 알겠는데 그 다음을 어떻게 해야할지 모르겠네영.. 구하시는 중간 값이 list의 중간에 있는 값이라면 아래와 같이 구하실 수 있습니다.... ',
#  '... 파이썬 초보입니다. c=[[1,2],[20,30]] 이라 할 때 c[0][1]+=c[1][1] print(c)을 입력 시 [[1,32],[20,30]] 가... 파이썬에 입력 시 32가 나오는데 왜 32인지 모르겠습니다. 2. 저 식에서 += 는 대체 뭐죠? 3. 대체 왜 print(c)가 [[1... ',
#  '파이썬으로 도형 그리기에서 if 조건문이랑 whlie 써서 저런식으로 프로그램 했는데 왜 오각형만 그려질까요?? 알고리즘 어떻게 짜야 하나요??  박스안에서 무한 반복을 하게 됩니다. 그래서 pentagon() 만 실행이 되고요. 그래서... ',
#  "파이썬 변수에 특수문자 지정을 하고 싶으면 어떻게 하나요? 밑처럼 했을 때 ! ! @ * # @ 이렇게 출력되었으면 좋겠어요 for i in '!!@*#@': A = i print(A)  #파이썬 #python for c in '!!@*#@': print(c) A나 i 둘 다... ",
#  '파이썬 리스트가 예를 들어서 A = [1,2,3,4]이면 0번째가 1로 출력되잖아요? 근데 리스트를 사용하되, 1번째가 1로... 파이썬 문법의 근간을 흔드는 일이 되겠네요. 임의적으로 index 0 에 쓰레기값을 넣어서 질문자만 알아서 사용해야... ',
#  "파이썬 for 문을 이용해서 * *** ***** *** * 이렇게 나오게 어떻게 만드나요? s = 2 x = 1 for i in range (1, 6) : print(' ' * s, end = '') print('*' * x) if i &gt;= 3 : s += 1 x -= 2 else : s -= 1 x += 2 ",
#  '파이썬 문제 질문드립니다 ㅠㅠ 1:1 질문 답변드립니다. n = int(input(&quot;: &quot;)) if n &gt;=0 and n &lt;=100 and n % 2 == 0 : print(True) else: print(False) ',
#  "파이썬 문제인데 모르겠어요 while True: n = input('이진수 입력 ') sum = 0 c = 0 for idx,d in enumerate(n): if d != '1' and d != '0': print('잘못된 이진수 다시 입력') c = 1 break if d == '1': sum += 2 ** ( len(n)... ",
#  '파이썬을 이제 막 배우고 있는데요.. gui는 화면을 만드는 거라고 알고있는데.... 굳이, 파이썬으로 만드는 이유가 있나요? 파이썬이란 언어는 보이는 모양... 파이썬으로 GUI를 만드는 건 화려하고 멋진 무언가를 만들기 위함이 아닌... ',
#  '파이썬 프로그래밍 문제인데 도저히 모르겠어서 올립니다ㅠ 아래 문제 해결해주실 수 있나요?... 테스트 후 루프 구조를 사용하여 파이썬 프로그램을 작성하여 모집단이 2만 명 미만이 되려면 몇 년이 걸릴지... ',
#  "위 사진애 나오는 프로그래밍 코드좀 짜주세요 파이썬이고 반복중첩문사용해주세요 age = int(input('만 나이 입력 : ')) year = int(input('출생연도 끝자리 입력 : ')) day =['금요일','월요일','화요일','수요일... ",
#  '안녕하세요 파이썬을 처음 시작하는 유저입니다. 파이썬에서 대표적으로 쓰는 라이브러리들은 무엇이 있는지... 코드를 개선해나가면서 이것저것 패키지를 많이 깔아야 될텐데 일반적으로 파이썬 쓰시면서 많이 쓰는 것들은... ',
#  "파이썬 현재 반복문까지 배웠습니다., 이 프로그램 짜는 방법이 너무 궁금합니다.. 되도록 간결하고 짧게 짜주시도록 부탁드립니다.ㅠ for i in range(5): print(&quot; &quot;*(5-i),end='') print(&quot;*&quot;*(i*2+1)) for i in range(4)... ",
#  '파이썬 독학 어떻게 해요?  파이썬이 쉽게 접할 수 있다고는 하나, 프로그래밍언어에 대한 기초적인 지식과 이해가... 이해가 어렵다면, 학원을 통해 도움을 받으셔야 할것 같습니다. &gt;&gt; 프로그래밍과정 문의 파이썬/자바/C언어 알아보기',
#  '파이썬학원추천 좀 해주세요 올해 고3이고 수험이 끝나서... 때 파이썬 배워두고 가면 좋다고 해서 배워볼 까 생각중입니다. 혹시, 서울 주변에 파이썬 학원으로 가장 괜찮은... 파이썬 과정이 필요하셔서 공부를 희망하신다고 말씀해... ',
#  '파이썬 코딩언어(?) Input() 이나 int()등 기초적으로 사용되는것들있잖아요... 지금 파이썬 공부하려는데 저런 기초적인단어가 무슨뜻인지 몰라서 자꾸... 파이썬 공부 하실 수 있는 인강 사이트 알려드리겠습니다. 참고해보세요. 현재... ',
#  '파이썬 코드 질문드립니다. 문자열에서 공백 기준으로 문자를 다... 이외에도, 파이썬과 관련하여 궁금한 것들이 있다면, 아래 제 블로그에... 글을 참고하시기 바랍니다 :D https://dinolabs.tistory.com/category/BLOG/파이썬 기초 ',
#  '클라우드 엔지니어에게 파이썬 코딩능력이 요구되기도 한다는데 파이썬의 자동화, 웹크롤러 관련되서 나오는 이야기... 클라우드 기술과 파이썬이 구체적으로 어떤 연관을 갖고 있는지 알고싶습니다. 실제로 클라우드기술자가 파이썬을... ',
#  "파이썬 두문제 질문입니다 ㅠㅠ! d = input('입력 :') if d.lower() in ['a','e','i','o','u']: print(f'{d} (은)는 모음입니다.') else: print(f'{d} (은)는 자음입니다.') a,b,c = map(int,input('세... ",
#  '파이썬 프로그램 짜기가 수행인데 (for문,if문 등등등 다 사욯해서 ) 어떻게 해야될지 감이 안잡혀요 ㅠㅠㅜㅜㅜ 도와주세요 엄청 쉽고 초등수준이여도 괜찮아요 ㅈㅂㅈㅂ  user = {} while True: choice... ',
#  '기초 설명 잘 해주는 파이썬강의 찾고 있어요. 가격... 계획이라 파이썬강의 외에 C언어강의도 수강할 수 있는 곳이면 좋겠습니다.  기초 설명 잘 해주는 파이썬강의 찾고... 그리고 추후 C언어도 공부할 계획이라 파이썬강의 외에... ',
#  '파이썬을 처음으로 배워보려고 유튜브를 따라하고 있는데 계속해서 디버그 실행하면 저렇게 나오고 연산결과가 안나와요.... 어떻게 해야할까요? 아래 명령창에 ps : c:￦ ....&gt; 상태 일때 수행하세요 아래가 python프롬프트... ',
#  "파이썬에서 'True' 라고 반환된 값은 문자열 데이터인가요? True', 또는... ※ 질문주신 내용 이외에도, 파이썬과 관련하여 궁금한 것들이 있다면... 참고하시기 바랍니다 :D https://dinolabs.tistory.com/category/BLOG/파이썬 기초 ",
#  '... 2학기부터 파이썬프로그래밍 수업을 공부한다고 하는데 학원에가서 전문적으로 배울 수 있는 파이썬프로그래밍... 파이썬프로그래밍 수업이 필요하셔서 교육기관을을... ㆍ프로그래밍언어 ( 파이썬 , C언어 , C++ ) ㆍ운영체제... ']

# %%
from sklearn.feature_extraction.text import CountVectorizer
from konlpy.tag import Okt

t = Okt()
vectorizer = CountVectorizer(min_df=1)

# %%
contents_tokens = [t.morphs(row) for row in contents]
contents_tokens
# Out:
# [['파이썬',
#   '은',
#   '백',
#   '준',
#   '기준',
#   '으로',
#   '브론즈',
#   '는',
#   '웬만큼',
#   '풀',
#   '줄',
#   '알',
#   '게',
#   '되었고',
#   '...',
#   '파이썬',
#   '공부',
#   '는',
#   '앞',
#   '으로',
#   '어떻게',
#   '해나',
#   '가면',
#   '좋을지',
#   '잘',
#   '모르겠습니다',
#   '.',
#   '아직',
#   '은',
#   '파이썬',
#   '초보',
#   '라고',
#   '생각',
#   '하기에',
#   '초보',
#   '에게',
#   '...',
#   '파이썬',
#   '과',
#   'C',
#   '언어',
#   '를',
#   '공부',
#   '하고',
#   '계신데요',
#   '.',
#   '기본',
#   '적',
#   '으로',
#   '...'],
#  ['파이썬',
#   '문제',
#   '해결',
#   'import',
#   'turtle',
#   'print',
#   "('",
#   '이',
#   '프로그램',
#   '은',
#   '다각형',
#   "')",
#   'd',
#   '=',
#   '100',
#   'while',
#   'True',
#   ':',
#   'n',
#   '=',
#   'input',
#   "('",
#   '원하는',
#   '다각형',
#   '(',
#   '3',
#   ',',
#   '4',
#   ',',
#   '5',
#   '종료',
#   ':',
#   'x',
#   ')',
#   "')",
#   'x',
#   ',',
#   'y',
#   '=',
#   'map',
#   '(',
#   'int',
#   ',',
#   'input',
#   "('",
#   '위치',
#   'x',
#   ',',
#   'y',
#   "').",
#   'split',
#   "(','))",
#   'turtle',
#   '.',
#   'penup',
#   '()',
#   'turtle',
#   '....'],
#  ['파이썬',
#   '코딩',
#   '이',
#   '거',
#   '어떻게',
#   '하는지',
#   '알려주세요',
#   'ㅠㅜ',
#   '내공',
#   '50',
#   '이요',
#   '!!',
#   'def',
#   'Pyung',
#   '2',
#   'msq',
#   '(',
#   'value',
#   '):',
#   'return',
#   'value',
#   '*',
#   '3.3',
#   'def',
#   'Msq',
#   '2',
#   'pyung',
#   '(',
#   'value',
#   '):',
#   'return',
#   'value',
#   '/',
#   '3.3',
#   'def',
#   'Cm',
#   '2',
#   'inch',
#   '(',
#   'value',
#   '):',
#   'return',
#   'value',
#   '*',
#   '0.394',
#   'def',
#   'Inch',
#   '2',
#   'cm',
#   '(',
#   'value',
#   ')...'],
#  ['저기',
#   '밑',
#   '에',
#   'SELF',
#   'STUDY',
#   '부분',
#   '파이썬',
#   '코딩',
#   '이',
#   '거',
#   '어떻게',
#   '하는지',
#   '알려주세요',
#   'ㅠㅜ',
#   '내공',
#   '100',
#   '이요',
#   '!!!',
#   'ss',
#   '=',
#   "'",
#   '파이썬',
#   '은',
#   '완전',
#   '재미있어요',
#   "'",
#   'sslen',
#   '=',
#   'len',
#   '(',
#   'ss',
#   ')',
#   'for',
#   'i',
#   'in',
#   'range',
#   '(',
#   '0',
#   ',',
#   'sslen',
#   ')',
#   ':',
#   'if',
#   'i',
#   '%',
#   '2',
#   '==',
#   '0',
#   ':',
#   'print',
#   '(',
#   'ss',
#   '[',
#   'i',
#   '],',
#   'end',
#   "='')",
#   'else',
#   '...'],
#  ['파이썬',
#   'for',
#   ',',
#   'while',
#   '문',
#   '연습',
#   '문제',
#   '로',
#   '나와있는',
#   '건데',
#   '요',
#   '위',
#   '그림',
#   '순서대로',
#   '(',
#   '1',
#   '),(',
#   '2',
#   '),(',
#   '3',
#   '),(',
#   '4',
#   ')',
#   '차례',
#   '로',
#   '...',
#   'D',
#   ':\\',
#   '파이썬',
#   '코드',
#   '\\',
#   'test',
#   '...'],
#  ['파이썬',
#   '문제',
#   '의',
#   '답',
#   '알려주세요',
#   '%%',
#   '이렇',
#   '게인',
#   '듯',
#   '?',
#   'import',
#   'time',
#   'now',
#   '=',
#   'time',
#   '.',
#   'time',
#   '()',
#   'sum',
#   '=',
#   '0',
#   'for',
#   'i',
#   'in',
#   'range',
#   '(',
#   '10000000',
#   '):',
#   'sum',
#   '+=',
#   '1',
#   'passed',
#   '_',
#   'time',
#   '=',
#   'time',
#   '.',
#   'time',
#   '()',
#   '-',
#   'now',
#   'print',
#   '(',
#   'f',
#   "'",
#   '계산',
#   '소요',
#   '시간',
#   ':',
#   '{',
#   'passed',
#   '_',
#   'time',
#   ':.',
#   '5',
#   'f',
#   '}',
#   '초',
#   "')"],
#  ['파이썬',
#   '에서',
#   '&',
#   'amp',
#   ';',
#   '은',
#   '뭔가',
#   '요',
#   '?',
#   '&',
#   'amp',
#   ';',
#   '는',
#   'bitwise',
#   'AND',
#   '라고',
#   '해서',
#   '2',
#   '진수',
#   '숫자',
#   '들',
#   '끼리',
#   '각',
#   '자릿수',
#   '를',
#   'AND',
#   '를',
#   '하는',
#   '겁니다',
#   '.',
#   '예',
#   '로',
#   '들어',
#   'a',
#   '=',
#   '14',
#   'b',
#   '=',
#   '4',
#   'print',
#   '(',
#   'b',
#   '&',
#   'amp',
#   ';',
#   'a',
#   ')',
#   '#',
#   '4',
#   '를',
#   '출력',
#   '.',
#   '0000',
#   '1110',
#   '(',
#   '14',
#   ')',
#   '&',
#   'amp',
#   ';',
#   '0000',
#   '0100',
#   '(',
#   '4',
#   ')',
#   '=',
#   '0000',
#   '0100'],
#  ['마인크래프트',
#   '파이썬',
#   '을',
#   '배워',
#   '보고',
#   '싶은데',
#   '배울',
#   '곳',
#   '없나요',
#   '?',
#   '그리고',
#   '그걸',
#   '적용',
#   '하는',
#   '방법',
#   '과',
#   '앱',
#   '까지',
#   '알',
#   '수',
#   '있는',
#   '곳',
#   '...',
#   '답변',
#   ':',
#   'be',
#   '는',
#   '파이썬',
#   '과',
#   '관련',
#   '없으므로',
#   'php',
#   '를',
#   '배워야',
#   '합니다',
#   '.',
#   '구글',
#   '에서',
#   'php',
#   '를',
#   '검색',
#   '하고',
#   '유튜브',
#   '강좌',
#   '를',
#   '이용',
#   '하세요',
#   '....'],
#  ['버튼',
#   '을',
#   '이용',
#   '하여',
#   'count',
#   'up',
#   ',',
#   'count',
#   'down',
#   ',',
#   '파이썬',
#   '종료',
#   '하는',
#   '윈도우',
#   '...',
#   'text',
#   '=&',
#   'quot',
#   ';',
#   '파이썬',
#   '종료',
#   '&',
#   'quot',
#   ';,',
#   'fg',
#   '=&',
#   'quot',
#   ';',
#   'red',
#   '&',
#   'quot',
#   ';,',
#   'command',
#   '=',
#   'quit',
#   ')',
#   'button',
#   '2',
#   '=',
#   'Button',
#   '(',
#   'window',
#   '...',
#   'config',
#   '(',
#   'text',
#   '=',
#   'str',
#   '(',
#   'number',
#   '))',
#   'button',
#   '1',
#   '=',
#   'Button',
#   '(',
#   'window',
#   ',',
#   'text',
#   '=&',
#   'quot',
#   ';',
#   '파이썬',
#   '종료',
#   '...'],
#  ['...',
#   '로',
#   '출력',
#   '되게',
#   '파이썬',
#   '에서',
#   '코딩',
#   '하려면',
#   '어떻게',
#   '해야하나요',
#   'ㅜㅠ',
#   '?',
#   '질문',
#   '의',
#   '정확한',
#   '의도',
#   '를',
#   '잘',
#   '모르지만',
#   '........',
#   'def',
#   'f',
#   '(',
#   'n',
#   ')',
#   ':',
#   'A',
#   '=',
#   '2',
#   '*(',
#   'n',
#   '-',
#   '1',
#   ')-',
#   '1',
#   'print',
#   '(',
#   'f',
#   "'",
#   'A',
#   '는',
#   '{',
#   'A',
#   '}',
#   '입니다',
#   ".')",
#   'f',
#   '(',
#   '10',
#   ')',
#   '======================',
#   'RESTART',
#   ':',
#   'D',
#   ':\\',
#   'python',
#   '39',
#   '\\',
#   '1',
#   '.',
#   'py',
#   '...'],
#  ['파이썬',
#   '으로',
#   '만들',
#   '수',
#   '있는',
#   '짧으면서',
#   '간단한',
#   '인공',
#   '지능',
#   '알려주세요',
#   '.',
#   '&',
#   'quot',
#   ';',
#   '짧으면서',
#   '간단',
#   '&',
#   'quot',
#   ';',
#   '한',
#   '이라는',
#   '게',
#   '사람',
#   '마다',
#   '...',
#   '파이썬',
#   'Python',
#   'Macro',
#   '구현',
#   'pyautogui',
#   '이미지',
#   '인식',
#   '하여',
#   '마우스',
#   '컨트롤',
#   '하는',
#   '법',
#   '+',
#   'opencv',
#   '-',
#   'python',
#   '(tistory.com',
#   ')',
#   '만들어진',
#   '...'],
#  ['파이썬',
#   '구동',
#   '을',
#   '위해',
#   '갖추어야',
#   '할',
#   '노트북',
#   '환경',
#   '은',
#   '어떻게',
#   '되나요',
#   '?',
#   '노트북',
#   '을',
#   '구매',
#   '할',
#   '때',
#   '고려',
#   '해야',
#   '할',
#   '사항',
#   '이',
#   '무엇',
#   '인지',
#   '...',
#   '파이썬',
#   '을',
#   '배우고',
#   '있는',
#   '중이',
#   '라면',
#   '당장',
#   '은',
#   '그렇게',
#   '좋은',
#   '사양',
#   '의',
#   '노트북',
#   '은',
#   '필요',
#   '없습니다',
#   '.',
#   '하지만',
#   '실력',
#   '이',
#   '좋아지고',
#   '다른',
#   '...'],
#  ['...',
#   '파이썬',
#   '라',
#   '이',
#   '버러',
#   '리',
#   '는',
#   '어디서',
#   '다운',
#   '받을수가',
#   '있나요',
#   '라이브러리',
#   '라는',
#   '뜻',
#   '은',
#   '특정',
#   '기능',
#   '을',
#   '만들어서',
#   '공통',
#   '으로',
#   '다른',
#   '...',
#   '일반',
#   '적',
#   '으로',
#   '파이썬',
#   '의',
#   '라이브러리',
#   '는',
#   'pip',
#   '이라는',
#   '명령',
#   '으로',
#   '설치',
#   '를',
#   '하는데요',
#   '.',
#   '(',
#   '이른바',
#   '공인',
#   '된',
#   '라이브러리',
#   ')',
#   '수학',
#   '적',
#   '인',
#   '...'],
#  ['파이썬',
#   '인강',
#   '이',
#   '필요해서',
#   '알아보고',
#   '있었는데요',
#   '.',
#   '오프라인',
#   '...',
#   '파이썬',
#   '를',
#   '인강',
#   '으로',
#   '배울',
#   '수',
#   '있게끔',
#   '잘',
#   '구성',
#   '되어',
#   '...',
#   '파이썬',
#   '인강',
#   '으로',
#   '쫌',
#   '유명한',
#   '홈페이지',
#   '나',
#   ',',
#   '학원',
#   '이',
#   '있다면',
#   '...',
#   '파이썬',
#   '인강',
#   '을',
#   '알아보고',
#   '계신다면',
#   '딱',
#   '좋은',
#   '학원',
#   '강의',
#   '가',
#   '있어서',
#   '...'],
#  ['사랑',
#   '의',
#   '방정식',
#   '을',
#   '파이썬',
#   '으로',
#   '돌릴',
#   '수',
#   '는',
#   '없나요',
#   '?',
#   '함수',
#   '축',
#   '이',
#   '나오는',
#   '것',
#   '까진',
#   '했는데',
#   '...',
#   'axis',
#   "('",
#   'equal',
#   "')",
#   'plt',
#   '.',
#   'plot',
#   '(',
#   'x',
#   ',',
#   'y',
#   ')',
#   'plt',
#   '.',
#   'title',
#   "('",
#   'fifth',
#   'heart',
#   'curve',
#   '|',
#   'parametric',
#   'equations',
#   "')",
#   'plt.show',
#   '()',
#   '#파이썬',
#   '#python'],
#  ['...',
#   '파이썬',
#   '으로',
#   '가능한가요',
#   '?',
#   '안되면',
#   '무슨',
#   '언어',
#   '로',
#   '하는',
#   '게',
#   '가장',
#   '편한가요',
#   '?',
#   '파이썬',
#   '으로',
#   'pystray',
#   '모듈',
#   '을',
#   '사용',
#   '하여',
#   '간편하게',
#   '만들수',
#   '있습니다',
#   '.',
#   '아래',
#   '코드',
#   '실행',
#   '해보세요',
#   '.',
#   '더',
#   '많은',
#   '것',
#   '이',
#   '궁금하시면',
#   '...'],
#  ['파이썬',
#   '에서',
#   '텍스트',
#   '에',
#   '특정',
#   '단어',
#   '여부',
#   '를',
#   '알아내는',
#   '알고리즘',
#   '을',
#   '만들고',
#   '싶은데',
#   '단어',
#   '가',
#   '한글',
#   '일',
#   '때',
#   '어떻게',
#   '해야',
#   '할까',
#   '요',
#   '..?',
#   's',
#   '=',
#   "'",
#   'show',
#   'me',
#   'the',
#   'money',
#   "'",
#   'a',
#   '=',
#   "'",
#   'me',
#   "'",
#   'b',
#   '=',
#   "'",
#   'THE',
#   "'",
#   'if',
#   'a',
#   'in',
#   's',
#   ':',
#   'print',
#   "('",
#   '있음',
#   "')",
#   'else',
#   ':',
#   'print',
#   "('",
#   '없음',
#   "')",
#   'if',
#   'b',
#   'in',
#   '...'],
#  ['파이썬',
#   'vscode',
#   '로',
#   '독학',
#   '해서',
#   '배우고',
#   '잇는데',
#   '파이썬',
#   '코드',
#   '실행',
#   '이',
#   '안됩니다',
#   '.',
#   '실행',
#   '버튼',
#   '이',
#   '있긴한데',
#   '다른',
#   '영상',
#   '들',
#   '과',
#   '...',
#   '전문가',
#   '분들',
#   '도와주세요',
#   'ㅜㅜ',
#   '처음',
#   '파이썬',
#   '하시는',
#   '것',
#   '이',
#   '라면',
#   'vscode',
#   '에서',
#   '하시는',
#   '것',
#   '보다는',
#   'IDLE',
#   '에서',
#   '하세요',
#   '.',
#   '파이썬',
#   '을',
#   '...'],
#  ['몇',
#   '년전',
#   '에',
#   '파이썬',
#   '이',
#   '제일',
#   '쉽다고',
#   '들은',
#   '것',
#   '같은데',
#   '요즘',
#   '도',
#   '그러나요',
#   '?',
#   '코딩',
#   '을',
#   '처음',
#   '접',
#   '하는',
#   '초보자',
#   '분들',
#   '이',
#   '파이썬',
#   '으로',
#   '코딩',
#   '공부',
#   '를',
#   '가장',
#   '많이',
#   '시작',
#   '하십니다',
#   '.',
#   'https://blog.naver.com/95shinha/222490214649'],
#  ['...',
#   '파이썬',
#   '입문',
#   '자',
#   '입니다',
#   '연습',
#   '문제',
#   '로',
#   '풀어',
#   '보려고',
#   '하는게',
#   '너무',
#   '어려워서',
#   '한번',
#   '여쭤',
#   '봅니다',
#   '.',
#   '조건',
#   '은',
#   '...',
#   'argv',
#   '[',
#   '1',
#   ':]',
#   'main',
#   '(',
#   'args',
#   ')',
#   '실행',
#   '이런',
#   '형태',
#   '로',
#   '입력',
#   '하는데',
#   '저',
#   '의',
#   '파이썬',
#   '파일',
#   '은',
#   'k',
#   '_',
#   '23',
#   '.',
#   'py',
#   '였어요',
#   '.',
#   '작성자',
#   '님',
#   '은',
#   '알맞게',
#   '...'],
#  ['[',
#   '퀴즈',
#   '1',
#   ',',
#   '퀴즈',
#   '2',
#   ',',
#   '퀴즈',
#   '3',
#   ']',
#   '이렇게',
#   '해서',
#   '코드',
#   '를',
#   '짠',
#   '다음',
#   '에',
#   '퀴즈',
#   '1',
#   '를',
#   '고르면',
#   '그',
#   '퀴즈',
#   '가',
#   '나오는',
#   '그런',
#   '코드',
#   '는',
#   '파이썬',
#   '에서는',
#   '못',
#   '짜나요',
#   '??',
#   '짤수',
#   '있다면',
#   '알려주실',
#   '수',
#   '있을까요',
#   '?',
#   '제',
#   '가',
#   '가진',
#   '내공',
#   '을',
#   '다',
#   '걸께요',
#   'ㅜㅠ',
#   '파이썬',
#   '에서',
#   '지원',
#   '하는',
#   '데이터',
#   '...'],
#  ['...',
#   '파이썬',
#   '관련',
#   '한가지',
#   '질문',
#   '을',
#   '드립니다',
#   '.',
#   '제',
#   '가',
#   'Jupiter',
#   'Notebook',
#   '을',
#   '사용',
#   '하고',
#   '있습니다',
#   '.',
#   '그리고',
#   '저',
#   '한테',
#   '...',
#   '제',
#   '가',
#   '아직',
#   '파이썬',
#   '을',
#   '공부',
#   '한지',
#   '얼마',
#   '안된',
#   '초보자',
#   '라',
#   '잘',
#   '모르겠습니다',
#   '.',
#   '어떤',
#   '식',
#   '으로',
#   '해야하는지',
#   '...'],
#  ['파이썬',
#   '공부',
#   '를',
#   '먼저',
#   '해야',
#   '할까',
#   '요',
#   '아니면',
#   '자격증',
#   '공부',
#   '하고',
#   '파이썬',
#   '으로',
#   '넘어가는게',
#   '좋을까요',
#   '?',
#   '응시',
#   '자격',
#   '조건',
#   '은',
#   '...',
#   '파이썬',
#   '책',
#   '과',
#   '파이썬',
#   '인강',
#   '병행',
#   '해서',
#   '공부',
#   '하시는',
#   '걸',
#   '추천',
#   '드립니다',
#   '.',
#   '궁금한',
#   '점',
#   '은',
#   '블로그',
#   '통해',
#   '글',
#   '남겨주세요',
#   '.'],
#  ['파이썬',
#   '을',
#   '이용',
#   '한',
#   '인공',
#   '지능',
#   '이',
#   '있을까요',
#   '?',
#   '파이썬',
#   '으로',
#   '어떤',
#   '인공',
#   '지능',
#   '을',
#   '만들',
#   '수',
#   '있나요',
#   '?',
#   '파이썬',
#   '(',
#   '코딩',
#   ')',
#   '도',
#   '...',
#   '안녕하세요',
#   ',',
#   '메',
#   '가',
#   'IT',
#   '진로',
#   '담당',
#   '컨설턴트',
#   '신짱',
#   '입니다',
#   '~~',
#   '인공',
#   '지능',
#   '기술',
#   '의',
#   '기반',
#   '이',
#   '되는',
#   '프로그래밍언어',
#   '가',
#   '파이썬',
#   '입니다',
#   '...'],
#  ['임의',
#   '의',
#   '숫자',
#   '를',
#   '입력',
#   '받아서',
#   '그',
#   '숫자',
#   '들',
#   '의',
#   '합계',
#   '와',
#   '각',
#   '숫자',
#   '들',
#   '의',
#   '비율',
#   '을',
#   '나타내는',
#   '파이썬',
#   '구현',
#   '할',
#   '수',
#   '있을까요',
#   '?',
#   'ex',
#   ')',
#   '입력',
#   '받은',
#   '시간',
#   '이',
#   '1',
#   ',',
#   '2',
#   ',',
#   '3',
#   '이',
#   '라면',
#   '합계',
#   '=',
#   '6',
#   'a',
#   '=',
#   '17',
#   'b',
#   '=',
#   '33',
#   'c',
#   '=',
#   '50',
#   'a',
#   '=',
#   'int',
#   '(',
#   'input',
#   "('",
#   '수',
#   '1',
#   '을',
#   '입력',
#   '하세요',
#   ':',
#   "'))",
#   'b',
#   '...'],
#  ['파이썬',
#   '에서',
#   'enumerate',
#   '는',
#   '언제',
#   '사용',
#   '하나요',
#   '?',
#   'enumerate',
#   '()',
#   '함수',
#   '는',
#   '주로',
#   '...',
#   '(',
#   '5,300',
#   ')',
#   '※',
#   '질문',
#   '주신',
#   '내용',
#   '이외',
#   '에도',
#   ',',
#   '파이썬',
#   '과',
#   '관련',
#   '하여',
#   '궁금한',
#   '...',
#   '참고',
#   '하시기',
#   '바랍니다',
#   ':',
#   'D',
#   'https://dinolabs.tistory.com/category/BLOG/',
#   '파이썬',
#   '기초'],
#  ['파이썬',
#   '독학',
#   '해도',
#   '괜찮을까요',
#   '?',
#   '제',
#   '가',
#   '파이썬',
#   '독학',
#   '을',
#   '해볼까',
#   '했는데',
#   '좀',
#   '힘든거',
#   '같아서',
#   '독학',
#   '안',
#   '하고',
#   '도움',
#   '을',
#   '받을',
#   '곳',
#   '에서',
#   '...',
#   '배워야',
#   '파이썬',
#   '독학',
#   '할',
#   '때',
#   '보다',
#   '더',
#   '좋을까요',
#   '?',
#   '파이썬',
#   '독학',
#   '하는것보다는',
#   '배우는게',
#   '더',
#   '도움',
#   '이',
#   '될거',
#   '같은데',
#   '혼자',
#   '독학',
#   '하다가',
#   '...'],
#  ['파이썬',
#   '을',
#   '잘',
#   '몰라서',
#   '질문',
#   '합니다',
#   '.',
#   '파이썬',
#   '으로',
#   '작성',
#   '한',
#   '코드',
#   '를',
#   '열람',
#   '이나',
#   '...',
#   '안녕하세요',
#   '파이썬',
#   '으로',
#   '작성',
#   '한',
#   '프로그램',
#   '을',
#   '다른',
#   '사람',
#   '들',
#   '이',
#   '해당',
#   '프로그램',
#   '의',
#   '...',
#   'pyinstaller',
#   '는',
#   '파이썬',
#   '프로그램',
#   '을',
#   'exe',
#   '파일',
#   '로',
#   '변환',
#   '을',
#   '해',
#   '주는',
#   '모듈',
#   '이기',
#   '때문',
#   '에',
#   '...'],
#  ['...',
#   '파이썬',
#   '세계',
#   '로',
#   '오',
#   '신',
#   '걸',
#   '환영',
#   '합니다',
#   '.',
#   '파이썬',
#   '은',
#   '비단',
#   '뱀',
#   '처럼',
#   '매력',
#   '적',
#   '인',
#   '언어',
#   '입니다',
#   '.&',
#   'quot',
#   ';&',
#   'quot',
#   ';&',
#   'quot',
#   ';',
#   'cnt',
#   '=',
#   '0',
#   '...',
#   '파이썬',
#   '세계',
#   '로',
#   '오',
#   '신',
#   '걸',
#   '환영',
#   '합니다',
#   '.',
#   '파이썬',
#   '은',
#   '비단',
#   '뱀',
#   '처럼',
#   '매력',
#   '적',
#   '인',
#   '언어',
#   '입니다',
#   '.&',
#   'quot',
#   ';&',
#   'quot',
#   ';&',
#   'quot',
#   ';',
#   'cnt',
#   '=',
#   '0',
#   '...'],
#  ['...',
#   '파이썬',
#   '의',
#   '속도',
#   '는',
#   'c',
#   ',',
#   'java',
#   '에',
#   '비교',
#   '하면',
#   '어느',
#   '정돈',
#   '가요',
#   '?',
#   '파이썬',
#   '의',
#   '속도',
#   '를',
#   '1',
#   '이라',
#   '가정',
#   '했을',
#   '때',
#   'c',
#   ',',
#   'java',
#   '의',
#   '수치',
#   '는',
#   '?',
#   '2',
#   '.',
#   '파이썬',
#   '은',
#   '1초',
#   '에',
#   '연산',
#   '을',
#   '몇번',
#   '하나요',
#   '?',
#   '1',
#   '.',
#   'https',
#   '...',
#   '파이썬',
#   '은',
#   'c',
#   '에',
#   '비',
#   '해서',
#   '71.90',
#   '배',
#   '느린',
#   '속도',
#   '로',
#   '연산',
#   '을',
#   '합니다',
#   '.',
#   '저',
#   '...'],
#  ['파이썬',
#   '으로',
#   'def',
#   '함수',
#   '하고',
#   '있는데',
#   '사진',
#   '처럼',
#   '계속',
#   '오류',
#   '가',
#   '나요',
#   '왜',
#   '그런',
#   '건가',
#   '요',
#   '??',
#   '계속',
#   'IDLE',
#   '에서만',
#   '하다가',
#   '파이썬',
#   '으로',
#   '직접',
#   '하는데',
#   '이러내요',
#   'IDLE',
#   '에서는',
#   '오류',
#   '가',
#   '안',
#   '나는데',
#   '파이썬',
#   '으로만',
#   '하면',
#   '오류',
#   '가',
#   '...'],
#  ['이',
#   '거',
#   '파이썬',
#   '어떻게',
#   '작성',
#   '하나요',
#   'ㅜㅜ',
#   'from',
#   'turtle',
#   'import',
#   '*',
#   'import',
#   'math',
#   'r',
#   '=',
#   'int',
#   '(',
#   'input',
#   "('",
#   '반지름',
#   "'))",
#   'while',
#   'True',
#   ':',
#   'd',
#   '=',
#   'int',
#   '(',
#   'input',
#   "('",
#   '도형',
#   "'))",
#   'if',
#   'd',
#   '&',
#   'gt',
#   ';=',
#   '3',
#   'and',
#   'd',
#   '&',
#   'lt',
#   ';=',
#   '6',
#   ':',
#   'break',
#   'x',
#   '=',
#   'int',
#   '(',
#   'input',
#   "('",
#   '원',
#   '둘레',
#   "'))",
#   'if',
#   'x',
#   ':',
#   'circle',
#   '...'],
#  ['파이썬',
#   '임의',
#   '의',
#   '난수',
#   '질문',
#   '드립니다',
#   '!',
#   'https://kin.naver.com/qna/detail.nhn?d1id=1&amp;dirId=1040201&amp;docId=401830375&amp;page=1#answer1',
#   '제',
#   '가',
#   '답변',
#   '하여',
#   '채택',
#   '된',
#   '글',
#   '입니다',
#   '.',
#   '동일한',
#   '문제',
#   '집',
#   '같습니다',
#   '.'],
#  ['...',
#   '혹시',
#   '파이썬',
#   '도',
#   '위',
#   '와',
#   '같이',
#   '창업',
#   '을',
#   '할',
#   '수',
#   '있는',
#   '방법',
#   '(?)',
#   '이',
#   '뭐',
#   '가',
#   '...',
#   '또한',
#   '웹',
#   '이나',
#   '앱',
#   '은',
#   '1',
#   '인',
#   '개발',
#   '이',
#   '가능한데',
#   '파이썬',
#   '으로',
#   '1',
#   '인',
#   '개발',
#   '로',
#   '...',
#   '파이썬',
#   '을',
#   '활용',
#   '한',
#   '1',
#   '인',
#   '창업',
#   '을',
#   '고민',
#   '하고',
#   '계신데요',
#   '.',
#   '파이썬',
#   '도',
#   'Django',
#   '프레임워크',
#   '를',
#   '활용',
#   '하면',
#   '웹',
#   '개발',
#   '을',
#   '할',
#   '수',
#   '...'],
#  ['메모장',
#   '에',
#   '파이썬',
#   '에서',
#   '실행',
#   '해야',
#   '할',
#   '명령',
#   '을',
#   '적어놓고',
#   '저장',
#   '해놓았다가',
#   '파이썬',
#   '에',
#   '이를',
#   '가져와서',
#   '실행',
#   '하고',
#   '싶은데',
#   '어떻게',
#   '해야하나요',
#   '?',
#   '질문',
#   '내용',
#   '을',
#   '보아',
#   '파이썬',
#   '코딩',
#   '을',
#   '메모장',
#   '에서',
#   '할',
#   '수',
#   '있느냐는',
#   '질문',
#   '으로',
#   '보입니다',
#   '.',
#   '메모장',
#   '에서',
#   '아래',
#   '와',
#   '...'],
#  ['제',
#   '가',
#   '파이썬',
#   '을',
#   '공부',
#   '하고',
#   '있는데',
#   '파이썬',
#   '파일',
#   '과',
#   '같은',
#   '위치',
#   '에',
#   '&',
#   'quot',
#   ';',
#   'a',
#   '.',
#   'txt',
#   '&',
#   'quot',
#   ';',
#   '라는',
#   '파일',
#   '을',
#   '만들고',
#   '싶어요',
#   '.',
#   '근데',
#   '만약',
#   '이미',
#   '있으면',
#   '만들',
#   '필요',
#   '가',
#   '없어서',
#   '실행',
#   '시키지',
#   '않고',
#   '싶은데',
#   '이',
#   '걸',
#   '어떻게',
#   '할까',
#   '요',
#   '?',
#   'if',
#   '문',
#   '을',
#   '쓰면',
#   '...'],
#  ['파이썬',
#   '질문',
#   '드려요',
#   'ㅠㅠㅠ',
#   '길이',
#   '단위',
#   '변환',
#   '하는',
#   '프로그램',
#   '을',
#   '파이썬',
#   '으로',
#   '하고',
#   '있는데',
#   '출력',
#   '을',
#   '하려고',
#   '하면',
#   '자꾸',
#   'dongDic',
#   '이',
#   '정의',
#   '되지',
#   '않았다고',
#   '오류',
#   '가',
#   '나오네요',
#   ',,,',
#   'ㅠㅠㅠㅠ',
#   '어떤',
#   '부분',
#   '이',
#   '오류',
#   '인가요',
#   '...',
#   'DongUnit',
#   '함수',
#   '에는',
#   'mm',
#   '를',
#   '...'],
#  ['파이썬',
#   '도형',
#   '그리기',
#   '각도',
#   '계산',
#   '하는',
#   '법',
#   '알려주세요',
#   '삼각형',
#   '/',
#   '사각형',
#   '/',
#   '오각형',
#   '부탁드립니다',
#   '.',
#   'turtle.circle',
#   '(&',
#   'lt',
#   ';',
#   '반지름',
#   '길이',
#   '&',
#   'gt',
#   ';,',
#   '360',
#   ',&',
#   'lt',
#   ';',
#   '꼭짓점',
#   '개수',
#   '&',
#   'gt',
#   ';)',
#   '위',
#   '와',
#   '같이',
#   '입력',
#   '하면',
#   '정다각형',
#   '을',
#   '그립니다',
#   '.',
#   '#파이썬',
#   '#python'],
#  ['파이썬',
#   '에서',
#   '+=',
#   '를',
#   '어떻게',
#   '읽나요',
#   '?',
#   '전',
#   '제',
#   '이름',
#   '은',
#   '복합',
#   '연산자',
#   ',',
#   '복합',
#   '대입',
#   '연산자',
#   '입니다',
#   '세부',
#   '이름',
#   '은',
#   '모르겠네요',
#   '.',
#   '자신',
#   '에',
#   '더하기',
#   '하기',
#   '?'],
#  ['아직',
#   '제',
#   '가',
#   '파이썬',
#   '에',
#   '대해',
#   '잘',
#   '몰라서',
#   '어디가',
#   '틀린지',
#   '...',
#   '파이썬',
#   '을',
#   '이제',
#   '막',
#   '대학교',
#   '에서',
#   '처음',
#   '배우고',
#   '있는데',
#   '숙제',
#   '를',
#   '...',
#   '시험',
#   '도',
#   '이제',
#   '한',
#   '달',
#   '밖에',
#   '안',
#   '남았는데',
#   '파이썬',
#   '은',
#   '벼락치기',
#   '...',
#   '파이썬',
#   '자체',
#   '는',
#   '어려운',
#   '프로그래밍',
#   '언어',
#   '는',
#   '아닙니다',
#   '.',
#   '다만',
#   '...'],
#  ['학교',
#   '정보',
#   '수행',
#   '이',
#   '파이썬',
#   '으로',
#   '뭐',
#   '를',
#   '만들어',
#   '오라',
#   '고',
#   '하셨는데',
#   '하나',
#   '도',
#   '모르겠어서',
#   '...',
#   '파이썬',
#   '리스트',
#   '로',
#   '간단한',
#   '예문',
#   '하나',
#   '만',
#   '만들어',
#   '주심',
#   '감사하겠습니다',
#   '.',
#   '내공',
#   '50',
#   '걸게요',
#   '.',
#   '가능한',
#   '빨리',
#   '부탁드립니다',
#   '.',
#   'import',
#   '...'],
#  ['파이썬',
#   '홐자',
#   '서',
#   '공부',
#   '하는',
#   '중',
#   '인데',
#   '4-22',
#   ',',
#   '23',
#   '을',
#   '못',
#   '풀겠습니다',
#   '도와주세요',
#   '#',
#   '4.22',
#   'import',
#   'datetime',
#   'date',
#   '=',
#   'datetime.datetime.now',
#   '()',
#   'y',
#   ',',
#   'm',
#   ',',
#   'd',
#   '=',
#   'date',
#   '.',
#   'year',
#   ',',
#   'date',
#   '.',
#   'month',
#   ',',
#   'date.day',
#   'print',
#   '(',
#   'f',
#   "'",
#   '현재',
#   '시간',
#   '은',
#   '{',
#   'y',
#   '}',
#   '년',
#   '{',
#   'm',
#   '}',
#   '월',
#   '{',
#   'd',
#   '}...'],
#  [';',
#   '를',
#   '파이썬',
#   '에서',
#   '왜',
#   '사용',
#   '하는지',
#   '역할',
#   '이',
#   '뭔',
#   '지',
#   '알려주세요',
#   '보통',
#   '프로그래밍',
#   '언어',
#   '에서',
#   '세미콜론',
#   '의',
#   '역할',
#   '은',
#   '그',
#   '문장',
#   '의',
#   '종료',
#   '를',
#   '나타냅니다',
#   '.',
#   '파이썬',
#   '같은',
#   '경우',
#   '는',
#   '굳이',
#   '안',
#   '써도',
#   '되지만',
#   '...',
#   '그냥',
#   '실수',
#   '로',
#   '쓴',
#   '것',
#   '같아',
#   '보입니다',
#   '.'],
#  ['파이썬',
#   '공부',
#   '중',
#   '입니다',
#   '.',
#   '파이썬',
#   '은',
#   '원래',
#   '오타',
#   '한번',
#   '나서',
#   '오류',
#   '나면',
#   '첨부',
#   '터',
#   '다시',
#   '써야',
#   '되나요',
#   '??',
#   '씨',
#   '플',
#   '플',
#   '이나',
#   '자바',
#   '는',
#   '...',
#   'IDLE',
#   '같은',
#   '파이썬',
#   '셸',
#   '에서',
#   '하기',
#   '때문',
#   '입니다',
#   '.',
#   'IDLE',
#   '같은',
#   '경우',
#   '에는',
#   '셸',
#   '에서',
#   '하지',
#   '마세요',
#   '.',
#   '셸',
#   '은',
#   '아래',
#   '의',
#   '사진',
#   '같은',
#   '화면',
#   '입니다',
#   '....'],
#  ['...',
#   '파이썬',
#   '으로',
#   '데이터',
#   '분석',
#   '등',
#   '을',
#   '할',
#   '수',
#   '있다고도',
#   '하고',
#   '반복',
#   '작업',
#   '을',
#   '할',
#   '수',
#   '있다고',
#   '하는데',
#   '혹시',
#   '엑셀',
#   '파일',
#   '로',
#   '정리',
#   '된',
#   '...',
#   '것',
#   '도',
#   '파이썬',
#   '으로',
#   '자동',
#   '등록',
#   '할',
#   '수',
#   '있는건',
#   '가요',
#   '?',
#   '웹',
#   '스크',
#   '래핑',
#   ',',
#   '크',
#   '롤링',
#   '으로',
#   '가능한',
#   '내용',
#   '입니다',
#   '.',
#   '데이터',
#   '분석',
#   '도',
#   'pandas',
#   '를',
#   '...'],
#  ['파이썬',
#   '실습',
#   '인데',
#   '특수문자',
#   '를',
#   '어떻게',
#   '공백',
#   '으로',
#   '바꾸어요',
#   '?',
#   'ㅜㅜ',
#   '음',
#   '이런',
#   '걸',
#   '말',
#   '하는건',
#   '가요',
#   '?',
#   'sp',
#   '=',
#   '&',
#   'quot',
#   ';~!@#$%^&',
#   'amp',
#   ';*-_+=(){}:;?.,&',
#   'lt',
#   ';&',
#   'gt',
#   ';&',
#   'quot',
#   ';',
#   'inputStr',
#   '=',
#   'input',
#   '()',
#   'outputStr',
#   '=',
#   '&',
#   'quot',
#   ';&',
#   'quot',
#   ';',
#   'for',
#   's',
#   'in',
#   'inputStr',
#   ':',
#   'if',
#   's',
#   'in',
#   'sp',
#   ':',
#   'outputStr',
#   '+=',
#   '&',
#   'quot',
#   ';',
#   '&',
#   'quot',
#   ';',
#   'else',
#   '...'],
#  ['사진',
#   '에',
#   '있는',
#   '파이썬',
#   '코딩',
#   '최대한',
#   '자세하게',
#   '설명',
#   '부탁드려요',
#   '가장',
#   '이해',
#   '가',
#   '안',
#   '되는',
#   '부분',
#   '은',
#   'import',
#   '아래',
#   '의',
#   'l',
#   '=[',
#   ']',
#   '이',
#   '부분',
#   '이',
#   '어떻게',
#   '쓰여지는',
#   '건지',
#   '모르겠어요',
#   '나머지',
#   '부분',
#   '도',
#   '설명',
#   '부탁드립니다',
#   '!!',
#   '#',
#   '랜덤',
#   '모듈',
#   '생',
#   '성',
#   'import',
#   '...'],
#  ['파이썬',
#   '으로',
#   '*',
#   '**',
#   '***',
#   '****',
#   '*****',
#   '******',
#   '*******',
#   '이',
#   '거',
#   '코딩',
#   '어떻게',
#   '해야',
#   '하나요',
#   '?',
#   'for',
#   '랑',
#   'while',
#   '둘',
#   '다',
#   '알려주세요',
#   'ㅠㅠㅠㅠㅠ',
#   'for',
#   'i',
#   'in',
#   'range',
#   '(',
#   '7',
#   '):',
#   'print',
#   "('",
#   "'*(",
#   '6',
#   '-',
#   'i',
#   '),',
#   'end',
#   "='')",
#   'print',
#   "('*",
#   "'*(",
#   'i',
#   '+',
#   '1',
#   '))'],
#  ['...',
#   '도와주세요',
#   'ㅜㅜ',
#   '파이썬',
#   '잘',
#   '하시는',
#   '분들',
#   '제발',
#   '...',
#   'score',
#   '=',
#   'int',
#   '(',
#   'input',
#   "('",
#   '기초',
#   '파이썬',
#   '예상',
#   '점수',
#   ':',
#   "'))",
#   'if',
#   'score',
#   '&',
#   'gt',
#   ';=',
#   '95',
#   ':',
#   'print',
#   "('",
#   '당신',
#   '의',
#   '기초',
#   '파이썬',
#   '학점',
#   '은',
#   'A',
#   '+',
#   '입니다',
#   ".')",
#   'elif',
#   'score',
#   '&',
#   'gt',
#   ';=',
#   '90',
#   ':',
#   'print',
#   "('",
#   '당신',
#   '의',
#   '기초',
#   '파이썬',
#   '학점',
#   '은',
#   'A',
#   '...'],
#  ['파이썬',
#   '공부',
#   '를',
#   '하는데',
#   '계속',
#   '오류',
#   '가',
#   '뜨더라구요',
#   '.',
#   'avg',
#   '안',
#   '에',
#   '들어갈',
#   '값',
#   '하고',
#   '7',
#   '번째',
#   '줄',
#   '에서',
#   '계속',
#   '오류',
#   '가',
#   '...',
#   '98',
#   '이',
#   '나와야',
#   '하는데',
#   '에러',
#   '만',
#   '뜨네요',
#   '…',
#   'raise',
#   '는',
#   '파이썬',
#   '에서',
#   '예외',
#   '를',
#   '발생',
#   '시키기',
#   '위',
#   '한',
#   '키',
#   '워드',
#   '입니다',
#   '....'],
#  ['...',
#   '최근',
#   '파이썬',
#   '언어',
#   '에',
#   '관심',
#   '이',
#   '생겨',
#   '학습',
#   '중',
#   '인',
#   '학생',
#   '입니다',
#   '.',
#   '최근',
#   '...',
#   '저',
#   '는',
#   '파이썬',
#   '을',
#   '무료',
#   '로',
#   '받아서',
#   '사용',
#   '하고',
#   '있는데',
#   '이',
#   '것',
#   '은',
#   '...',
#   '제',
#   '가',
#   '만약',
#   '무료',
#   '인',
#   '파이썬',
#   '을',
#   '사용',
#   '해서',
#   '모듈',
#   '이나',
#   '소프트웨어',
#   '를',
#   '제작',
#   '한',
#   '다',
#   '면',
#   ',',
#   '제',
#   '가',
#   '제작',
#   '한',
#   '제',
#   '작물',
#   '은',
#   '파이썬',
#   '...'],
#  ['파이썬',
#   '설치',
#   '를',
#   '하려고',
#   '하는데',
#   '최신',
#   '버전',
#   '은',
#   '10',
#   '이상만',
#   '된다고',
#   '하네요',
#   '..',
#   '윈도우',
#   '7',
#   '에',
#   '파이썬',
#   '설치',
#   '하려면',
#   '전',
#   '...',
#   '모르겠어요',
#   'ㅠㅠㅠㅠ',
#   '파이썬',
#   '공식',
#   '홈페이지',
#   '에서',
#   'win',
#   '7',
#   '지원',
#   '하는',
#   '마지막',
#   '버전',
#   '링크',
#   '드립니다',
#   '.',
#   '64',
#   '비트',
#   '컴퓨터',
#   '...'],
#  ['파이썬',
#   '코딩',
#   '을',
#   '시작',
#   '하려고',
#   '하는데요',
#   '유튜브',
#   '와',
#   '책',
#   '을',
#   '보면서',
#   '독학',
#   '하려',
#   '하는데',
#   '책',
#   '(',
#   '기초',
#   ')',
#   '과',
#   '파이썬',
#   '설치',
#   '할',
#   '때',
#   '...',
#   '강',
#   '좌라면',
#   '노마드',
#   '코더',
#   '(https://nomadcoders.co',
#   ')',
#   '의',
#   '무료',
#   '파이썬',
#   '웹',
#   '스크',
#   '래퍼',
#   '강좌',
#   '봤고',
#   ',',
#   '그',
#   '밖에는',
#   '인터넷',
#   '특히',
#   '...'],
#  ['제',
#   '가',
#   '파이썬',
#   '을',
#   '배워',
#   '볼까',
#   '하는데요',
#   '.',
#   '웹사이트',
#   '정도',
#   '만들려면',
#   '몇',
#   '년',
#   '걸리나요',
#   '?',
#   '웹사이트',
#   '를',
#   '만들고',
#   '싶다면',
#   '파이썬',
#   '을',
#   '...',
#   '파이썬',
#   '을',
#   '여쭤',
#   '보셨으니',
#   ',',
#   '이',
#   '에',
#   '맞춰',
#   '답변',
#   '드리자면',
#   ',',
#   '파이썬',
#   '에서',
#   'Django',
#   '라는',
#   '프레임워크',
#   '가',
#   '있습니다',
#   '.',
#   '파이썬',
#   '으로',
#   '...'],
#  ['파이썬',
#   '을',
#   '혼자',
#   '해볼려고',
#   '하는데',
#   '아래',
#   '사진',
#   '들',
#   '처럼',
#   '뜨면서',
#   '실행',
#   '이',
#   '안됩니다',
#   '.',
#   '어떻게',
#   '해야',
#   '되나요',
#   '??',
#   'visual',
#   'studio',
#   '...',
#   '일단',
#   'd',
#   '.',
#   'py',
#   '파이썬',
#   '프로그램',
#   '은',
#   '이상',
#   '이',
#   '없고요',
#   '.',
#   '실행',
#   '한',
#   '것',
#   '을',
#   '보니',
#   ',',
#   '그',
#   '부분',
#   '이',
#   '잘',
#   '못',
#   '된',
#   '것',
#   '을',
#   '보니',
#   ',',
#   '파이썬',
#   '실행',
#   '...'],
#  ['파이썬',
#   '을',
#   '이용',
#   '해',
#   '간단하게',
#   'rpg',
#   '형식',
#   '의',
#   '일부분',
#   '을',
#   '구현',
#   '하고',
#   '싶은데요',
#   '.',
#   '몬스터',
#   'HP',
#   '=',
#   '1000',
#   '이고',
#   '파이썬',
#   '사용자',
#   '한테',
#   '직접',
#   '수치',
#   '를',
#   '입력',
#   '받아서',
#   '몬스터',
#   'HP',
#   '=',
#   '0',
#   '이',
#   '될',
#   '때',
#   '까지',
#   '계속',
#   '사용자',
#   '로부터',
#   '특정',
#   '수치',
#   '를',
#   '입력',
#   '받고',
#   '...'],
#  ['파이썬',
#   '교재',
#   '를',
#   '보는데',
#   '16',
#   '진수',
#   '출력',
#   '하는',
#   '서식',
#   '문자',
#   '는',
#   '%',
#   'x',
#   '이고',
#   '16',
#   '진수',
#   '의',
#   '경우',
#   '포맷팅',
#   '에',
#   '사용',
#   '하는',
#   '표현',
#   '은',
#   '%',
#   'h',
#   '라고',
#   '나와있는데',
#   '둘',
#   '이',
#   '서로',
#   '다른',
#   '게',
#   '맞나요',
#   '?',
#   '%',
#   'x',
#   '가',
#   '맞아요',
#   '%',
#   'h',
#   '는',
#   'hour',
#   '로',
#   '시간',
#   '을',
#   '나타내기',
#   '위해',
#   '...'],
#  ['...',
#   '파이썬',
#   '으로',
#   '이렇게',
#   '출력',
#   '되게',
#   '하려면',
#   '어떻게',
#   '해야하나요',
#   '?',
#   '다음',
#   '과',
#   '...',
#   'center',
#   '(',
#   '24',
#   ',',
#   "'",
#   "')",
#   'print',
#   '(',
#   'star',
#   ')',
#   '※',
#   '질문',
#   '주신',
#   '내용',
#   '이외',
#   '에도',
#   ',',
#   '파이썬',
#   '과',
#   '...',
#   '참고',
#   '하시기',
#   '바랍니다',
#   ':',
#   'D',
#   'https://dinolabs.tistory.com/category/BLOG/',
#   '파이썬',
#   '기초'],
#  ['파이썬',
#   '문제',
#   '질문',
#   '드립니다',
#   '5.11',
#   '전번',
#   '문제',
#   '를',
#   '알아야지',
#   '정확합니다만',
#   '나름',
#   '풀이',
#   'import',
#   'random',
#   'n',
#   '1',
#   '=',
#   'random',
#   '.',
#   'randint',
#   '(',
#   '11',
#   ',',
#   '99',
#   ')',
#   'n',
#   '2',
#   '=',
#   'random',
#   '.',
#   'randint',
#   '(',
#   '11',
#   ',',
#   '99',
#   ')',
#   'dap',
#   '=',
#   'n',
#   '1',
#   '-',
#   'n',
#   '2',
#   'idap',
#   '=',
#   'int',
#   '(',
#   'input',
#   '(',
#   'str',
#   '(',
#   'n',
#   '1',
#   ")+'",
#   '-',
#   "'+",
#   'str',
#   '(',
#   'n',
#   '2',
#   ")+'",
#   '=',
#   "'))",
#   'if',
#   'dap',
#   '...'],
#  ['...',
#   '생겨',
#   '파이썬',
#   '을',
#   '독학',
#   '해보려',
#   '합니다',
#   '.',
#   '파이썬',
#   '은',
#   '빅데이터',
#   '에',
#   '유리하다고',
#   '들었습니다',
#   '.',
#   '독학',
#   '을',
#   '할',
#   '때',
#   ',',
#   '파이썬',
#   '으로',
#   '...',
#   '그리고',
#   ',',
#   '파이썬',
#   '을',
#   '쓰는',
#   '가장',
#   '주된',
#   '이유',
#   '가',
#   '무엇',
#   '인가요',
#   '?',
#   '파이썬',
#   '을',
#   '학습',
#   '후',
#   'r',
#   '언어',
#   '와',
#   '하둡',
#   '을',
#   '배우시는걸',
#   '추천',
#   '드립니다',
#   '.',
#   '파이썬',
#   '을',
#   '...'],
#  ['...',
#   '1',
#   '}',
#   '파이썬',
#   '문제',
#   '가',
#   '이렇게',
#   '되어있는데',
#   '코딩',
#   '을',
#   '어떻게',
#   '해야',
#   '할까',
#   '요',
#   '??',
#   '#',
#   '-',
#   'make',
#   '_',
#   'word',
#   '_',
#   'count',
#   '()',
#   '함수',
#   '를',
#   '...',
#   '1',
#   '}',
#   '#',
#   '파이썬',
#   '문제',
#   '가',
#   '이렇게',
#   '되어있는데',
#   '코딩',
#   '을',
#   '어떻게',
#   '해야',
#   '할까',
#   '요',
#   '??',
#   'print',
#   '(',
#   'make',
#   '_',
#   'word',
#   '_',
#   'count',
#   "('",
#   'data',
#   '....'],
#  ['...',
#   '아니면',
#   '파이썬',
#   '공부',
#   '를',
#   '먼저',
#   '해야',
#   '할까',
#   '요',
#   '?',
#   '파이썬',
#   '과',
#   '정보처리기사',
#   '중',
#   '고민',
#   '을',
#   '...',
#   '◐',
#   'IT',
#   '분야',
#   '자격증',
#   ',',
#   '교육',
#   '과정',
#   '*',
#   'IT',
#   '베이직',
#   ':',
#   'C',
#   '언어',
#   ',',
#   '파이썬',
#   ',',
#   '자바',
#   '프로그램',
#   '등',
#   '...',
#   'R',
#   '과',
#   '파이썬',
#   '을',
#   '기본',
#   '으로',
#   '하는',
#   '과정',
#   '*',
#   '정보보안',
#   '전문가',
#   ':',
#   '시스템',
#   '과',
#   '네트워크',
#   '...'],
#  ['15',
#   '개',
#   '의',
#   '값',
#   '을',
#   '입력',
#   '받고',
#   ',',
#   '리스트',
#   '에',
#   '저장',
#   '후',
#   ',',
#   '중복',
#   '되는',
#   '값',
#   '을',
#   '제거',
#   '한',
#   '리스트',
#   '출력',
#   '하기',
#   '파이썬',
#   '코딩',
#   '짜주세요',
#   '..',
#   'ㅠ',
#   'values',
#   '=',
#   '[]',
#   'for',
#   '_',
#   'in',
#   'range',
#   '(',
#   '15',
#   '):',
#   'values',
#   '.',
#   'append',
#   '(',
#   'input',
#   '())',
#   'values',
#   '=',
#   'list',
#   '(',
#   'set',
#   '(',
#   'values',
#   '))'],
#  ['파이썬',
#   '코드',
#   '짠',
#   '걸',
#   '저장',
#   '하려면',
#   '어떻게',
#   '해야하나요',
#   '?',
#   'idle',
#   '에디터',
#   '에서',
#   '하신건',
#   '가요',
#   '?',
#   'file',
#   '-&',
#   'gt',
#   ';',
#   'Save',
#   'as',
#   '저장',
#   '할',
#   '폴더',
#   '지정',
#   '하고',
#   '(',
#   '그냥',
#   '하시면',
#   '기본',
#   '위치',
#   '에',
#   ')',
#   '이름',
#   '지정',
#   '하고',
#   '저장',
#   '버튼'],
#  ['파이썬',
#   '이',
#   '거',
#   '어떻게',
#   '하나요',
#   '..?',
#   'import',
#   'sys',
#   ',',
#   'os',
#   'for',
#   'i',
#   'in',
#   '(',
#   '2',
#   ',',
#   '6',
#   '):',
#   'for',
#   'j',
#   'in',
#   'range',
#   '(',
#   '1',
#   ',',
#   '10',
#   '):',
#   'for',
#   'k',
#   'in',
#   'range',
#   '(',
#   'i',
#   ',',
#   'i',
#   '+',
#   '4',
#   '):',
#   'print',
#   '(&',
#   'quot',
#   ';{',
#   '0',
#   '}*{',
#   '1',
#   '}={',
#   '2',
#   '}&',
#   'quot',
#   ';.',
#   'format',
#   '(',
#   'k',
#   ',',
#   'j',
#   ',',
#   'k',
#   '*',
#   'j',
#   '),',
#   'end',
#   "='\\",
#   't',
#   "')",
#   'print',
#   '()',
#   'print',
#   '()'],
#  ['...',
#   '그리고',
#   '파이썬',
#   '으로',
#   '1',
#   '부터',
#   '200',
#   '까지의',
#   '홀수',
#   '의',
#   '합수',
#   '짝수',
#   '의',
#   '합',
#   '수',
#   '어케',
#   '구',
#   '하나요',
#   '쉽게',
#   '설명',
#   '부탁드려요',
#   'ㅠㅠ',
#   '...',
#   '그리고',
#   '파이썬',
#   '으로',
#   '1',
#   '부터',
#   '200',
#   '까지의',
#   '홀수',
#   '의',
#   '합수',
#   '짝수',
#   '의',
#   '합',
#   '수',
#   '어케',
#   '구',
#   '하나요',
#   '쉽게',
#   '설명',
#   '부탁드려요',
#   'ㅠㅠ',
#   '...'],
#  ['...',
#   '파이썬',
#   '언어',
#   '에서',
#   '조건문',
#   '에',
#   '사용',
#   '되는',
#   '관계',
#   '연산자',
#   '중',
#   '‘',
#   '같지',
#   '않다',
#   '’',
#   '를',
#   '쓰시오',
#   '2',
#   '.',
#   '파이썬',
#   '언어',
#   '에서',
#   '조건문',
#   '에',
#   '사용',
#   '되는',
#   '관계',
#   '연가',
#   '자',
#   '중',
#   '‘',
#   '같다',
#   '’',
#   '를',
#   '쓰시오',
#   '1',
#   '.',
#   '파이썬',
#   '언어',
#   '에서',
#   '...',
#   '=',
#   '2',
#   '.',
#   '파이썬',
#   '언어',
#   '에서',
#   '조건문',
#   '에',
#   '사용',
#   '되는',
#   '관계',
#   '연가',
#   '자',
#   '중',
#   '...'],
#  ['파이썬',
#   '에',
#   'avg',
#   '()',
#   '나',
#   'average',
#   '()',
#   '이런',
#   '함수',
#   '없나요',
#   '?',
#   '파이썬',
#   '에서',
#   '평균',
#   '을',
#   '구',
#   '하는',
#   '함수',
#   '가',
#   '없습니다',
#   '.',
#   '따라서',
#   '아래',
#   '와',
#   '...',
#   '※',
#   '질문',
#   '주신',
#   '내용',
#   '이외',
#   '에도',
#   ',',
#   '파이썬',
#   '과',
#   '관련',
#   '하여',
#   '...',
#   '바랍니다',
#   ':',
#   'D',
#   'https://dinolabs.tistory.com/category/BLOG/',
#   '파이썬',
#   '기초'],
#  ['...',
#   '점수',
#   '는',
#   '실수',
#   '나',
#   '문자',
#   '가',
#   '입력',
#   '되면',
#   '체크',
#   '하여',
#   '다시',
#   '입력',
#   '해야',
#   '한다',
#   '.',
#   '를',
#   '파이썬',
#   '으로',
#   '어떻게',
#   '나타내나요',
#   '?',
#   'scores',
#   '=',
#   "{'",
#   '과제',
#   "':",
#   '0',
#   ",'",
#   '중간',
#   "':",
#   '0',
#   ",'",
#   '기',
#   '말',
#   "':",
#   '0',
#   '}',
#   'for',
#   'i',
#   'in',
#   'scores',
#   '.',
#   'keys',
#   '():',
#   'while',
#   'True',
#   ':',
#   'd',
#   '=',
#   'input',
#   "('",
#   '성적',
#   '입력',
#   "('",
#   '+',
#   'i',
#   "+')",
#   "')",
#   'if',
#   'd',
#   '.',
#   'isdigit',
#   '...'],
#  ['파이썬',
#   '에서',
#   '폴더',
#   '를',
#   '삭제',
#   '하려면',
#   '어떻게',
#   '해야하나요',
#   '?',
#   'rmdir',
#   '()',
#   '함수',
#   '와',
#   '...',
#   '이외',
#   '에도',
#   ',',
#   '파이썬',
#   '과',
#   '관련',
#   '하여',
#   '궁금한',
#   '것',
#   '들',
#   '이',
#   '있다면',
#   ',',
#   '아래',
#   '제',
#   '...',
#   '참고',
#   '하시기',
#   '바랍니다',
#   ':',
#   'D',
#   'https://dinolabs.tistory.com/category/BLOG/',
#   '파이썬',
#   '기초'],
#  ['파이썬',
#   '3.8',
#   '.',
#   '9',
#   '사용',
#   '중',
#   '이고',
#   'talib',
#   '모듈',
#   '파이썬',
#   '3.8',
#   '용',
#   '버전',
#   '으로',
#   'pip',
#   'install',
#   '하여',
#   '.',
#   'py',
#   '로는',
#   '실행',
#   '이',
#   '잘',
#   '되는데',
#   'exe',
#   '패키징',
#   '하면',
#   '실행',
#   '이',
#   '안되네요',
#   'pyinstaller',
#   '실행',
#   '될',
#   '때',
#   '사용',
#   '되는',
#   '파이썬',
#   '버전',
#   '때문',
#   '인가요',
#   '?...'],
#  ['파이썬',
#   '인강',
#   '괜찮은',
#   '사이트',
#   '추천',
#   '해주세요',
#   '.',
#   '아이',
#   '가',
#   '배우려기',
#   '...',
#   '설명',
#   '해주는',
#   '파이썬',
#   '인강',
#   '사이트',
#   '찾고있습니다',
#   '.',
#   '괜찮은',
#   '학원',
#   '있으면',
#   '...',
#   '아예',
#   '파이썬',
#   '인강',
#   '보다는',
#   '기초',
#   '통합',
#   '과정',
#   '인강',
#   '을',
#   '들어',
#   '보시',
#   '는',
#   '것',
#   '도',
#   '추천',
#   '드리고',
#   '있습니다',
#   '.',
#   '아래',
#   '는',
#   '파이썬',
#   '이',
#   '...'],
#  ['파이썬',
#   'idle',
#   '를',
#   '처음',
#   '하는데',
#   '코드',
#   '를',
#   '입력',
#   '하고',
#   '엔터',
#   '를',
#   '누른',
#   '뒤',
#   '에',
#   '확인',
#   '해보니',
#   '코드',
#   '가',
#   '틀렸는데',
#   '그럼',
#   '코드',
#   '를',
#   '어떻게',
#   '...',
#   '파이썬',
#   '의',
#   'idle',
#   '는',
#   '두',
#   '가지',
#   '모드',
#   '가',
#   '있습니다',
#   '.',
#   '1',
#   '.',
#   '다이렉트',
#   '모드',
#   '또는',
#   '직접',
#   '모드',
#   '라고',
#   '하여',
#   '한',
#   '줄',
#   '씩',
#   '코드',
#   '를',
#   '작성',
#   '하여',
#   '...'],
#  ['프로그래밍',
#   '좀',
#   '배워',
#   '보려고',
#   '하는데',
#   '자바',
#   '와',
#   '파이썬',
#   '중',
#   '어느',
#   '것',
#   '...',
#   '자바',
#   '와',
#   '파이썬',
#   '중',
#   '먼저',
#   '배울',
#   '프로그래밍',
#   '언어',
#   '를',
#   '고민',
#   '하고',
#   '계시군요',
#   '.',
#   '둘',
#   '다',
#   '배우실',
#   '생각',
#   '이',
#   '시',
#   '라면',
#   '파이썬',
#   '부터',
#   '...',
#   '둘다',
#   '쓰임',
#   '새',
#   '가',
#   '다양하고',
#   '요즘',
#   '인기',
#   '있는',
#   '언어',
#   '인데',
#   '파이썬',
#   '...'],
#  ['파이썬',
#   '독학',
#   '하려고',
#   '하는데요',
#   '...',
#   '내용',
#   '이',
#   '쉽지는',
#   '않겠지만',
#   '그래도',
#   '...',
#   '요새',
#   '파이썬',
#   '독학',
#   '에',
#   '도움',
#   '이',
#   '될만',
#   '한',
#   '인강',
#   '사이트',
#   '는',
#   '어디',
#   '일까',
#   '요',
#   '?',
#   '파이썬',
#   '독학',
#   '하려고',
#   '하시나',
#   '봐요',
#   '!',
#   '여러가지',
#   '다양한',
#   '인강',
#   '사이트',
#   '에서',
#   '파이썬',
#   '독학',
#   '에',
#   '도움',
#   '이',
#   '되',
#   '실만',
#   '한',
#   '인강',
#   '을',
#   '...'],
#  ['제',
#   '가',
#   '이제',
#   '파이썬',
#   '입문',
#   '했는데요',
#   '..',
#   'txt',
#   '파일',
#   '에',
#   '들어가',
#   '맨',
#   '앞',
#   '자리',
#   '숫자',
#   '를',
#   '바꾸는',
#   '프로그램',
#   '짤려는데',
#   '어케',
#   '...',
#   '고수',
#   '님',
#   '들',
#   '알려주세요',
#   'ㅠㅠ',
#   '내공',
#   '100',
#   '검',
#   '#',
#   '제',
#   '가',
#   '이제',
#   '파이썬',
#   '입문',
#   '했는데요',
#   '..',
#   'txt',
#   '파일',
#   '에',
#   '들어가',
#   '맨',
#   '...'],
#  ['중간',
#   '값',
#   '을',
#   '도출',
#   '하는',
#   '파이썬',
#   '에서',
#   '문자',
#   '를',
#   '작은',
#   '순서대로',
#   '나열한',
#   '것',
#   '은',
#   '알겠는데',
#   '그',
#   '다음',
#   '을',
#   '어떻게',
#   '해야',
#   '할지',
#   '모르겠',
#   '네',
#   '영',
#   '..',
#   '구',
#   '하시는',
#   '중간',
#   '값',
#   '이',
#   'list',
#   '의',
#   '중간',
#   '에',
#   '있는',
#   '값',
#   '이',
#   '라면',
#   '아래',
#   '와',
#   '같이',
#   '구',
#   '하실',
#   '수',
#   '있습니다',
#   '....'],
#  ['...',
#   '파이썬',
#   '초보',
#   '입니다',
#   '.',
#   'c',
#   '=[[',
#   '1',
#   ',',
#   '2',
#   '],[',
#   '20',
#   ',',
#   '30',
#   ']]',
#   '이라',
#   '할',
#   '때',
#   'c',
#   '[',
#   '0',
#   '][',
#   '1',
#   ']+=',
#   'c',
#   '[',
#   '1',
#   '][',
#   '1',
#   ']',
#   'print',
#   '(',
#   'c',
#   ')',
#   '을',
#   '입력',
#   '시',
#   '[[',
#   '1',
#   ',',
#   '32',
#   '],[',
#   '20',
#   ',',
#   '30',
#   ']]',
#   '가',
#   '...',
#   '파이썬',
#   '에',
#   '입력',
#   '시',
#   '32',
#   '가',
#   '나오는데',
#   '왜',
#   '32',
#   '인지',
#   '모르겠습니다',
#   '.',
#   '2',
#   '.',
#   '저',
#   '식',
#   '에서',
#   '+=',
#   '는',
#   '대체',
#   '뭐',
#   '죠',
#   '?',
#   '3',
#   '.',
#   '대체',
#   '왜',
#   'print',
#   '(',
#   'c',
#   ')',
#   '가',
#   '[[',
#   '1',
#   '...'],
#  ['파이썬',
#   '으로',
#   '도형',
#   '그리기',
#   '에서',
#   'if',
#   '조건문',
#   '이랑',
#   'whlie',
#   '써서',
#   '저런',
#   '식',
#   '으로',
#   '프로그램',
#   '했는데',
#   '왜',
#   '오각형',
#   '만',
#   '그려질까',
#   '요',
#   '??',
#   '알고리즘',
#   '어떻게',
#   '짜야',
#   '하나요',
#   '??',
#   '박스',
#   '안',
#   '에서',
#   '무한',
#   '반복',
#   '을',
#   '하게',
#   '됩니다',
#   '.',
#   '그래서',
#   'pentagon',
#   '()',
#   '만',
#   '실행',
#   '이',
#   '되고요',
#   '.',
#   '그래서',
#   '...'],
#  ['파이썬',
#   '변수',
#   '에',
#   '특수문자',
#   '지정',
#   '을',
#   '하고',
#   '싶으면',
#   '어떻게',
#   '하나요',
#   '?',
#   '밑',
#   '처럼',
#   '했을',
#   '때',
#   '!',
#   '!',
#   '@',
#   '*',
#   '#',
#   '@',
#   '이렇게',
#   '출력',
#   '되었으면',
#   '좋겠어요',
#   'for',
#   'i',
#   'in',
#   "'!!@*#@':",
#   'A',
#   '=',
#   'i',
#   'print',
#   '(',
#   'A',
#   ')',
#   '#파이썬',
#   '#python',
#   'for',
#   'c',
#   'in',
#   "'!!@*#@':",
#   'print',
#   '(',
#   'c',
#   ')',
#   'A',
#   '나',
#   'i',
#   '둘',
#   '다',
#   '...'],
#  ['파이썬',
#   '리스트',
#   '가',
#   '예',
#   '를',
#   '들어서',
#   'A',
#   '=',
#   '[',
#   '1',
#   ',',
#   '2',
#   ',',
#   '3',
#   ',',
#   '4',
#   ']',
#   '이면',
#   '0',
#   '번',
#   '째',
#   '가',
#   '1',
#   '로',
#   '출력',
#   '되잖아요',
#   '?',
#   '근데',
#   '리스트',
#   '를',
#   '사용',
#   '하',
#   '되',
#   ',',
#   '1',
#   '번',
#   '째',
#   '가',
#   '1',
#   '로',
#   '...',
#   '파이썬',
#   '문법',
#   '의',
#   '근간',
#   '을',
#   '흔드는',
#   '일이',
#   '되겠네요',
#   '.',
#   '임의',
#   '적',
#   '으로',
#   'index',
#   '0',
#   '에',
#   '쓰레기',
#   '값',
#   '을',
#   '넣어서',
#   '질문',
#   '자만',
#   '알아서',
#   '사용',
#   '해야',
#   '...'],
#  ['파이썬',
#   'for',
#   '문',
#   '을',
#   '이용',
#   '해서',
#   '*',
#   '***',
#   '*****',
#   '***',
#   '*',
#   '이렇게',
#   '나오게',
#   '어떻게',
#   '만드나',
#   '요',
#   '?',
#   's',
#   '=',
#   '2',
#   'x',
#   '=',
#   '1',
#   'for',
#   'i',
#   'in',
#   'range',
#   '(',
#   '1',
#   ',',
#   '6',
#   ')',
#   ':',
#   'print',
#   "('",
#   "'",
#   '*',
#   's',
#   ',',
#   'end',
#   '=',
#   "'')",
#   'print',
#   "('*'",
#   '*',
#   'x',
#   ')',
#   'if',
#   'i',
#   '&',
#   'gt',
#   ';=',
#   '3',
#   ':',
#   's',
#   '+=',
#   '1',
#   'x',
#   '-=',
#   '2',
#   'else',
#   ':',
#   's',
#   '-=',
#   '1',
#   'x',
#   '+=',
#   '2'],
#  ['파이썬',
#   '문제',
#   '질문',
#   '드립니다',
#   'ㅠㅠ',
#   '1:1',
#   '질문',
#   '답변',
#   '드립니다',
#   '.',
#   'n',
#   '=',
#   'int',
#   '(',
#   'input',
#   '(&',
#   'quot',
#   ';:',
#   '&',
#   'quot',
#   ';))',
#   'if',
#   'n',
#   '&',
#   'gt',
#   ';=',
#   '0',
#   'and',
#   'n',
#   '&',
#   'lt',
#   ';=',
#   '100',
#   'and',
#   'n',
#   '%',
#   '2',
#   '==',
#   '0',
#   ':',
#   'print',
#   '(',
#   'True',
#   ')',
#   'else',
#   ':',
#   'print',
#   '(',
#   'False',
#   ')'],
#  ['파이썬',
#   '문제',
#   '인데',
#   '모르겠어요',
#   'while',
#   'True',
#   ':',
#   'n',
#   '=',
#   'input',
#   "('",
#   '이진수',
#   '입력',
#   "')",
#   'sum',
#   '=',
#   '0',
#   'c',
#   '=',
#   '0',
#   'for',
#   'idx',
#   ',',
#   'd',
#   'in',
#   'enumerate',
#   '(',
#   'n',
#   '):',
#   'if',
#   'd',
#   '!=',
#   "'",
#   '1',
#   "'",
#   'and',
#   'd',
#   '!=',
#   "'",
#   '0',
#   "':",
#   'print',
#   "('",
#   '잘',
#   '못',
#   '된',
#   '이진수',
#   '다시',
#   '입력',
#   "')",
#   'c',
#   '=',
#   '1',
#   'break',
#   'if',
#   'd',
#   '==',
#   "'",
#   '1',
#   "':",
#   'sum',
#   '+=',
#   '2',
#   '**',
#   '(',
#   'len',
#   '(',
#   'n',
#   ')...'],
#  ['파이썬',
#   '을',
#   '이제',
#   '막',
#   '배우고',
#   '있는데요',
#   '..',
#   'gui',
#   '는',
#   '화면',
#   '을',
#   '만드는',
#   '거',
#   '라고',
#   '알고있는데',
#   '....',
#   '굳이',
#   ',',
#   '파이썬',
#   '으로',
#   '만드는',
#   '이유',
#   '가',
#   '있나요',
#   '?',
#   '파이썬',
#   '이란',
#   '언어',
#   '는',
#   '보이는',
#   '모양',
#   '...',
#   '파이썬',
#   '으로',
#   'GUI',
#   '를',
#   '만드는',
#   '건',
#   '화려하고',
#   '멋진',
#   '무언가',
#   '를',
#   '만들기',
#   '위함',
#   '이',
#   '아닌',
#   '...'],
#  ['파이썬',
#   '프로그래밍',
#   '문제',
#   '인데',
#   '도저히',
#   '모르겠어서',
#   '올립니다',
#   'ㅠ',
#   '아래',
#   '문제',
#   '해결',
#   '해주실',
#   '수',
#   '있나요',
#   '?...',
#   '테스트',
#   '후',
#   '루프',
#   '구조',
#   '를',
#   '사용',
#   '하여',
#   '파이썬',
#   '프로그램',
#   '을',
#   '작성',
#   '하여',
#   '모집단',
#   '이',
#   '2만',
#   '명',
#   '미만',
#   '이',
#   '되려면',
#   '몇',
#   '년',
#   '이',
#   '걸릴지',
#   '...'],
#  ['위',
#   '사진',
#   '애',
#   '나오는',
#   '프로그래밍',
#   '코드',
#   '좀',
#   '짜주세요',
#   '파이썬',
#   '이고',
#   '반복',
#   '중',
#   '첩',
#   '문',
#   '사용',
#   '해주세요',
#   'age',
#   '=',
#   'int',
#   '(',
#   'input',
#   "('",
#   '만',
#   '나이',
#   '입력',
#   ':',
#   "'))",
#   'year',
#   '=',
#   'int',
#   '(',
#   'input',
#   "('",
#   '출생',
#   '연도',
#   '끝',
#   '자리',
#   '입력',
#   ':',
#   "'))",
#   'day',
#   "=['",
#   '금요일',
#   "','",
#   '월요일',
#   "','",
#   '화요일',
#   "','",
#   '수요일',
#   '...'],
#  ['안녕하세요',
#   '파이썬',
#   '을',
#   '처음',
#   '시작',
#   '하는',
#   '유저',
#   '입니다',
#   '.',
#   '파이썬',
#   '에서',
#   '대표',
#   '적',
#   '으로',
#   '쓰는',
#   '라이브러리',
#   '들',
#   '은',
#   '무엇',
#   '이',
#   '있는지',
#   '...',
#   '코드',
#   '를',
#   '개선',
#   '해나가면서',
#   '이',
#   '것',
#   '저',
#   '것',
#   '패키지',
#   '를',
#   '많이',
#   '깔아야',
#   '될텐데',
#   '일반',
#   '적',
#   '으로',
#   '파이썬',
#   '쓰시면서',
#   '많이',
#   '쓰는',
#   '것',
#   '들',
#   '은',
#   '...'],
#  ['파이썬',
#   '현재',
#   '반복',
#   '문',
#   '까지',
#   '배웠습니다',
#   '.,',
#   '이',
#   '프로그램',
#   '짜는',
#   '방법',
#   '이',
#   '너무',
#   '궁금합니다',
#   '..',
#   '되도록',
#   '간결하고',
#   '짧게',
#   '짜주시도록',
#   '부탁드립니다',
#   '.',
#   'ㅠ',
#   'for',
#   'i',
#   'in',
#   'range',
#   '(',
#   '5',
#   '):',
#   'print',
#   '(&',
#   'quot',
#   ';',
#   '&',
#   'quot',
#   ';*(',
#   '5',
#   '-',
#   'i',
#   '),',
#   'end',
#   "='')",
#   'print',
#   '(&',
#   'quot',
#   ';*&',
#   'quot',
#   ';*(',
#   'i',
#   '*',
#   '2',
#   '+',
#   '1',
#   '))',
#   'for',
#   'i',
#   'in',
#   'range',
#   '(',
#   '4',
#   ')...'],
#  ['파이썬',
#   '독학',
#   '어떻게',
#   '해',
#   '요',
#   '?',
#   '파이썬',
#   '이',
#   '쉽게',
#   '접',
#   '할',
#   '수',
#   '있다고는',
#   '하나',
#   ',',
#   '프로그래밍언어',
#   '에',
#   '대한',
#   '기초',
#   '적',
#   '인',
#   '지식',
#   '과',
#   '이해',
#   '가',
#   '...',
#   '이해',
#   '가',
#   '어렵다면',
#   ',',
#   '학원',
#   '을',
#   '통해',
#   '도움',
#   '을',
#   '받으셔야',
#   '할것',
#   '같습니다',
#   '.',
#   '&',
#   'gt',
#   ';&',
#   'gt',
#   ';',
#   '프로그래밍',
#   '과정',
#   '문의',
#   '파이썬',
#   '/',
#   '자바',
#   '/',
#   'C',
#   '언어',
#   '알아보기'],
#  ['파이썬',
#   '학원',
#   '추천',
#   '좀',
#   '해주세요',
#   '올해',
#   '고',
#   '3',
#   '이고',
#   '수험',
#   '이',
#   '끝나서',
#   '...',
#   '때',
#   '파이썬',
#   '배워',
#   '두고',
#   '가면',
#   '좋다고',
#   '해서',
#   '배워',
#   '볼',
#   '까',
#   '생각',
#   '중',
#   '입니다',
#   '.',
#   '혹시',
#   ',',
#   '서울',
#   '주변',
#   '에',
#   '파이썬',
#   '학원',
#   '으로',
#   '가장',
#   '괜찮은',
#   '...',
#   '파이썬',
#   '과정',
#   '이',
#   '필요하셔서',
#   '공부',
#   '를',
#   '희망',
#   '하신다고',
#   '말씀',
#   '해',
#   '...'],
#  ['파이썬',
#   '코딩',
#   '언어',
#   '(?)',
#   'Input',
#   '()',
#   '이나',
#   'int',
#   '()',
#   '등',
#   '기초',
#   '적',
#   '으로',
#   '사용',
#   '되는것',
#   '들있잖아요',
#   '...',
#   '지금',
#   '파이썬',
#   '공부',
#   '하려는데',
#   '저런',
#   '기초',
#   '적',
#   '인',
#   '단어',
#   '가',
#   '무슨',
#   '뜻',
#   '인지',
#   '몰라서',
#   '자꾸',
#   '...',
#   '파이썬',
#   '공부',
#   '하실',
#   '수',
#   '있는',
#   '인강',
#   '사이트',
#   '알려',
#   '드리겠습니다',
#   '.',
#   '참고',
#   '해보세요',
#   '.',
#   '현재',
#   '...'],
#  ['파이썬',
#   '코드',
#   '질문',
#   '드립니다',
#   '.',
#   '문자열',
#   '에서',
#   '공백',
#   '기준',
#   '으로',
#   '문자',
#   '를',
#   '다',
#   '...',
#   '이외',
#   '에도',
#   ',',
#   '파이썬',
#   '과',
#   '관련',
#   '하여',
#   '궁금한',
#   '것',
#   '들',
#   '이',
#   '있다면',
#   ',',
#   '아래',
#   '제',
#   '블로그',
#   '에',
#   '...',
#   '글',
#   '을',
#   '참고',
#   '하시기',
#   '바랍니다',
#   ':',
#   'D',
#   'https://dinolabs.tistory.com/category/BLOG/',
#   '파이썬',
#   '기초'],
#  ['클라우드',
#   '엔지니어',
#   '에게',
#   '파이썬',
#   '코딩',
#   '능력',
#   '이',
#   '요구',
#   '되',
#   '기도',
#   '한다는데',
#   '파이썬',
#   '의',
#   '자동화',
#   ',',
#   '웹크롤러',
#   '관련',
#   '되서',
#   '나오는',
#   '이야기',
#   '...',
#   '클라우드',
#   '기술',
#   '과',
#   '파이썬',
#   '이',
#   '구체',
#   '적',
#   '으로',
#   '어떤',
#   '연관',
#   '을',
#   '갖고',
#   '있는지',
#   '알고싶습니다',
#   '.',
#   '실제',
#   '로',
#   '클라우드',
#   '기술자',
#   '가',
#   '파이썬',
#   '을',
#   '...'],
#  ['파이썬',
#   '두',
#   '문제',
#   '질문',
#   '입니다',
#   'ㅠㅠ',
#   '!',
#   'd',
#   '=',
#   'input',
#   "('",
#   '입력',
#   ":')",
#   'if',
#   'd',
#   '.',
#   'lower',
#   '()',
#   'in',
#   "['",
#   'a',
#   "','",
#   'e',
#   "','",
#   'i',
#   "','",
#   'o',
#   "','",
#   'u',
#   "']:",
#   'print',
#   '(',
#   'f',
#   "'{",
#   'd',
#   '}',
#   '(',
#   '은',
#   ')',
#   '는',
#   '모음',
#   '입니다',
#   ".')",
#   'else',
#   ':',
#   'print',
#   '(',
#   'f',
#   "'{",
#   'd',
#   '}',
#   '(',
#   '은',
#   ')',
#   '는',
#   '자음',
#   '입니다',
#   ".')",
#   'a',
#   ',',
#   'b',
#   ',',
#   'c',
#   '=',
#   'map',
#   '(',
#   'int',
#   ',',
#   'input',
#   "('",
#   '세',
#   '...'],
#  ['파이썬',
#   '프로그램',
#   '짜기가',
#   '수행',
#   '인데',
#   '(',
#   'for',
#   '문',
#   ',',
#   'if',
#   '문',
#   '등등',
#   '등',
#   '다',
#   '사욯해',
#   '서',
#   ')',
#   '어떻게',
#   '해야',
#   '될지',
#   '감',
#   '이',
#   '안',
#   '잡혀요',
#   'ㅠㅠㅜㅜㅜ',
#   '도와주세요',
#   '엄청',
#   '쉽고',
#   '초',
#   '등수',
#   '준이여도',
#   '괜찮아요',
#   'ㅈㅂㅈㅂ',
#   'user',
#   '=',
#   '{}',
#   'while',
#   'True',
#   ':',
#   'choice',
#   '...'],
#  ['기초',
#   '설명',
#   '잘',
#   '해주는',
#   '파이썬',
#   '강의',
#   '찾고',
#   '있어요',
#   '.',
#   '가격',
#   '...',
#   '계획',
#   '이라',
#   '파이썬',
#   '강의',
#   '외',
#   '에',
#   'C',
#   '언어',
#   '강의',
#   '도',
#   '수강',
#   '할',
#   '수',
#   '있는',
#   '곳',
#   '이',
#   '면',
#   '좋겠습니다',
#   '.',
#   '기초',
#   '설명',
#   '잘',
#   '해주는',
#   '파이썬',
#   '강의',
#   '찾고',
#   '...',
#   '그리고',
#   '추후',
#   'C',
#   '언어',
#   '도',
#   '공부',
#   '할',
#   '계획',
#   '이라',
#   '파이썬',
#   '강의',
#   '외',
#   '에',
#   '...'],
#  ['파이썬',
#   '을',
#   '처음',
#   '으로',
#   '배워',
#   '보려고',
#   '유튜브',
#   '를',
#   '따라하고',
#   '있는데',
#   '계속',
#   '해서',
#   '디버그',
#   '실행',
#   '하면',
#   '저렇게',
#   '나오고',
#   '연산',
#   '결과',
#   '가',
#   '안',
#   '나와요',
#   '....',
#   '어떻게',
#   '해야',
#   '할까',
#   '요',
#   '?',
#   '아래',
#   '명령',
#   '창',
#   '에',
#   'ps',
#   ':',
#   'c',
#   ':',
#   '￦',
#   '....&',
#   'gt',
#   ';',
#   '상태',
#   '일',
#   '때',
#   '수행',
#   '하세요',
#   '아래',
#   '가',
#   'python',
#   '프롬',
#   '프트',
#   '...'],
#  ['파이썬',
#   '에서',
#   "'",
#   'True',
#   "'",
#   '라고',
#   '반환',
#   '된',
#   '값',
#   '은',
#   '문자열',
#   '데이터',
#   '인가요',
#   '?',
#   'True',
#   "',",
#   '또는',
#   '...',
#   '※',
#   '질문',
#   '주신',
#   '내용',
#   '이외',
#   '에도',
#   ',',
#   '파이썬',
#   '과',
#   '관련',
#   '하여',
#   '궁금한',
#   '것',
#   '들',
#   '이',
#   '있다면',
#   '...',
#   '참고',
#   '하시기',
#   '바랍니다',
#   ':',
#   'D',
#   'https://dinolabs.tistory.com/category/BLOG/',
#   '파이썬',
#   '기초'],
#  ['...',
#   '2',
#   '학기',
#   '부터',
#   '파이썬',
#   '프로그래밍',
#   '수업',
#   '을',
#   '공부',
#   '한다고',
#   '하는데',
#   '학원',
#   '에가',
#   '서',
#   '전문',
#   '적',
#   '으로',
#   '배울',
#   '수',
#   '있는',
#   '파이썬',
#   '프로그래밍',
#   '...',
#   '파이썬',
#   '프로그래밍',
#   '수업',
#   '이',
#   '필요하셔서',
#   '교육',
#   '기관',
#   '을',
#   '을',
#   '...',
#   'ㆍ',
#   '프로그래밍언어',
#   '(',
#   '파이썬',
#   ',',
#   'C',
#   '언어',
#   ',',
#   'C',
#   '++',
#   ')',
#   'ㆍ',
#   '운영체제',
#   '...']]

# %%
contents_for_vectorize = []

for content in contents_tokens:
    sentence = ''
    for word in content:
        sentence = sentence + ' ' + word
    
    contents_for_vectorize.append(sentence)

contents_for_vectorize
# Out:
# [' 파이썬 은 백 준 기준 으로 브론즈 는 웬만큼 풀 줄 알 게 되었고 ... 파이썬 공부 는 앞 으로 어떻게 해나 가면 좋을지 잘 모르겠습니다 . 아직 은 파이썬 초보 라고 생각 하기에 초보 에게 ... 파이썬 과 C 언어 를 공부 하고 계신데요 . 기본 적 으로 ...',
#  " 파이썬 문제 해결 import turtle print (' 이 프로그램 은 다각형 ') d = 100 while True : n = input (' 원하는 다각형 ( 3 , 4 , 5 종료 : x ) ') x , y = map ( int , input (' 위치 x , y '). split (',')) turtle . penup () turtle ....",
#  ' 파이썬 코딩 이 거 어떻게 하는지 알려주세요 ㅠㅜ 내공 50 이요 !! def Pyung 2 msq ( value ): return value * 3.3 def Msq 2 pyung ( value ): return value / 3.3 def Cm 2 inch ( value ): return value * 0.394 def Inch 2 cm ( value )...',
#  " 저기 밑 에 SELF STUDY 부분 파이썬 코딩 이 거 어떻게 하는지 알려주세요 ㅠㅜ 내공 100 이요 !!! ss = ' 파이썬 은 완전 재미있어요 ' sslen = len ( ss ) for i in range ( 0 , sslen ) : if i % 2 == 0 : print ( ss [ i ], end ='') else ...",
#  ' 파이썬 for , while 문 연습 문제 로 나와있는 건데 요 위 그림 순서대로 ( 1 ),( 2 ),( 3 ),( 4 ) 차례 로 ... D :\\ 파이썬 코드 \\ test ...',
#  " 파이썬 문제 의 답 알려주세요 %% 이렇 게인 듯 ? import time now = time . time () sum = 0 for i in range ( 10000000 ): sum += 1 passed _ time = time . time () - now print ( f ' 계산 소요 시간 : { passed _ time :. 5 f } 초 ')",
#  ' 파이썬 에서 & amp ; 은 뭔가 요 ? & amp ; 는 bitwise AND 라고 해서 2 진수 숫자 들 끼리 각 자릿수 를 AND 를 하는 겁니다 . 예 로 들어 a = 14 b = 4 print ( b & amp ; a ) # 4 를 출력 . 0000 1110 ( 14 ) & amp ; 0000 0100 ( 4 ) = 0000 0100',
#  ' 마인크래프트 파이썬 을 배워 보고 싶은데 배울 곳 없나요 ? 그리고 그걸 적용 하는 방법 과 앱 까지 알 수 있는 곳 ... 답변 : be 는 파이썬 과 관련 없으므로 php 를 배워야 합니다 . 구글 에서 php 를 검색 하고 유튜브 강좌 를 이용 하세요 ....',
#  ' 버튼 을 이용 하여 count up , count down , 파이썬 종료 하는 윈도우 ... text =& quot ; 파이썬 종료 & quot ;, fg =& quot ; red & quot ;, command = quit ) button 2 = Button ( window ... config ( text = str ( number )) button 1 = Button ( window , text =& quot ; 파이썬 종료 ...',
#  " ... 로 출력 되게 파이썬 에서 코딩 하려면 어떻게 해야하나요 ㅜㅠ ? 질문 의 정확한 의도 를 잘 모르지만 ........ def f ( n ) : A = 2 *( n - 1 )- 1 print ( f ' A 는 { A } 입니다 .') f ( 10 ) ====================== RESTART : D :\\ python 39 \\ 1 . py ...",
#  ' 파이썬 으로 만들 수 있는 짧으면서 간단한 인공 지능 알려주세요 . & quot ; 짧으면서 간단 & quot ; 한 이라는 게 사람 마다 ... 파이썬 Python Macro 구현 pyautogui 이미지 인식 하여 마우스 컨트롤 하는 법 + opencv - python (tistory.com ) 만들어진 ...',
#  ' 파이썬 구동 을 위해 갖추어야 할 노트북 환경 은 어떻게 되나요 ? 노트북 을 구매 할 때 고려 해야 할 사항 이 무엇 인지 ... 파이썬 을 배우고 있는 중이 라면 당장 은 그렇게 좋은 사양 의 노트북 은 필요 없습니다 . 하지만 실력 이 좋아지고 다른 ...',
#  ' ... 파이썬 라 이 버러 리 는 어디서 다운 받을수가 있나요 라이브러리 라는 뜻 은 특정 기능 을 만들어서 공통 으로 다른 ... 일반 적 으로 파이썬 의 라이브러리 는 pip 이라는 명령 으로 설치 를 하는데요 . ( 이른바 공인 된 라이브러리 ) 수학 적 인 ...',
#  ' 파이썬 인강 이 필요해서 알아보고 있었는데요 . 오프라인 ... 파이썬 를 인강 으로 배울 수 있게끔 잘 구성 되어 ... 파이썬 인강 으로 쫌 유명한 홈페이지 나 , 학원 이 있다면 ... 파이썬 인강 을 알아보고 계신다면 딱 좋은 학원 강의 가 있어서 ...',
#  " 사랑 의 방정식 을 파이썬 으로 돌릴 수 는 없나요 ? 함수 축 이 나오는 것 까진 했는데 ... axis (' equal ') plt . plot ( x , y ) plt . title (' fifth heart curve | parametric equations ') plt.show () #파이썬 #python",
#  ' ... 파이썬 으로 가능한가요 ? 안되면 무슨 언어 로 하는 게 가장 편한가요 ? 파이썬 으로 pystray 모듈 을 사용 하여 간편하게 만들수 있습니다 . 아래 코드 실행 해보세요 . 더 많은 것 이 궁금하시면 ...',
#  " 파이썬 에서 텍스트 에 특정 단어 여부 를 알아내는 알고리즘 을 만들고 싶은데 단어 가 한글 일 때 어떻게 해야 할까 요 ..? s = ' show me the money ' a = ' me ' b = ' THE ' if a in s : print (' 있음 ') else : print (' 없음 ') if b in ...",
#  ' 파이썬 vscode 로 독학 해서 배우고 잇는데 파이썬 코드 실행 이 안됩니다 . 실행 버튼 이 있긴한데 다른 영상 들 과 ... 전문가 분들 도와주세요 ㅜㅜ 처음 파이썬 하시는 것 이 라면 vscode 에서 하시는 것 보다는 IDLE 에서 하세요 . 파이썬 을 ...',
#  ' 몇 년전 에 파이썬 이 제일 쉽다고 들은 것 같은데 요즘 도 그러나요 ? 코딩 을 처음 접 하는 초보자 분들 이 파이썬 으로 코딩 공부 를 가장 많이 시작 하십니다 . https://blog.naver.com/95shinha/222490214649',
#  ' ... 파이썬 입문 자 입니다 연습 문제 로 풀어 보려고 하는게 너무 어려워서 한번 여쭤 봅니다 . 조건 은 ... argv [ 1 :] main ( args ) 실행 이런 형태 로 입력 하는데 저 의 파이썬 파일 은 k _ 23 . py 였어요 . 작성자 님 은 알맞게 ...',
#  ' [ 퀴즈 1 , 퀴즈 2 , 퀴즈 3 ] 이렇게 해서 코드 를 짠 다음 에 퀴즈 1 를 고르면 그 퀴즈 가 나오는 그런 코드 는 파이썬 에서는 못 짜나요 ?? 짤수 있다면 알려주실 수 있을까요 ? 제 가 가진 내공 을 다 걸께요 ㅜㅠ 파이썬 에서 지원 하는 데이터 ...',
#  ' ... 파이썬 관련 한가지 질문 을 드립니다 . 제 가 Jupiter Notebook 을 사용 하고 있습니다 . 그리고 저 한테 ... 제 가 아직 파이썬 을 공부 한지 얼마 안된 초보자 라 잘 모르겠습니다 . 어떤 식 으로 해야하는지 ...',
#  ' 파이썬 공부 를 먼저 해야 할까 요 아니면 자격증 공부 하고 파이썬 으로 넘어가는게 좋을까요 ? 응시 자격 조건 은 ... 파이썬 책 과 파이썬 인강 병행 해서 공부 하시는 걸 추천 드립니다 . 궁금한 점 은 블로그 통해 글 남겨주세요 .',
#  ' 파이썬 을 이용 한 인공 지능 이 있을까요 ? 파이썬 으로 어떤 인공 지능 을 만들 수 있나요 ? 파이썬 ( 코딩 ) 도 ... 안녕하세요 , 메 가 IT 진로 담당 컨설턴트 신짱 입니다 ~~ 인공 지능 기술 의 기반 이 되는 프로그래밍언어 가 파이썬 입니다 ...',
#  " 임의 의 숫자 를 입력 받아서 그 숫자 들 의 합계 와 각 숫자 들 의 비율 을 나타내는 파이썬 구현 할 수 있을까요 ? ex ) 입력 받은 시간 이 1 , 2 , 3 이 라면 합계 = 6 a = 17 b = 33 c = 50 a = int ( input (' 수 1 을 입력 하세요 : ')) b ...",
#  ' 파이썬 에서 enumerate 는 언제 사용 하나요 ? enumerate () 함수 는 주로 ... ( 5,300 ) ※ 질문 주신 내용 이외 에도 , 파이썬 과 관련 하여 궁금한 ... 참고 하시기 바랍니다 : D https://dinolabs.tistory.com/category/BLOG/ 파이썬 기초',
#  ' 파이썬 독학 해도 괜찮을까요 ? 제 가 파이썬 독학 을 해볼까 했는데 좀 힘든거 같아서 독학 안 하고 도움 을 받을 곳 에서 ... 배워야 파이썬 독학 할 때 보다 더 좋을까요 ? 파이썬 독학 하는것보다는 배우는게 더 도움 이 될거 같은데 혼자 독학 하다가 ...',
#  ' 파이썬 을 잘 몰라서 질문 합니다 . 파이썬 으로 작성 한 코드 를 열람 이나 ... 안녕하세요 파이썬 으로 작성 한 프로그램 을 다른 사람 들 이 해당 프로그램 의 ... pyinstaller 는 파이썬 프로그램 을 exe 파일 로 변환 을 해 주는 모듈 이기 때문 에 ...',
#  ' ... 파이썬 세계 로 오 신 걸 환영 합니다 . 파이썬 은 비단 뱀 처럼 매력 적 인 언어 입니다 .& quot ;& quot ;& quot ; cnt = 0 ... 파이썬 세계 로 오 신 걸 환영 합니다 . 파이썬 은 비단 뱀 처럼 매력 적 인 언어 입니다 .& quot ;& quot ;& quot ; cnt = 0 ...',
#  ' ... 파이썬 의 속도 는 c , java 에 비교 하면 어느 정돈 가요 ? 파이썬 의 속도 를 1 이라 가정 했을 때 c , java 의 수치 는 ? 2 . 파이썬 은 1초 에 연산 을 몇번 하나요 ? 1 . https ... 파이썬 은 c 에 비 해서 71.90 배 느린 속도 로 연산 을 합니다 . 저 ...',
#  ' 파이썬 으로 def 함수 하고 있는데 사진 처럼 계속 오류 가 나요 왜 그런 건가 요 ?? 계속 IDLE 에서만 하다가 파이썬 으로 직접 하는데 이러내요 IDLE 에서는 오류 가 안 나는데 파이썬 으로만 하면 오류 가 ...',
#  " 이 거 파이썬 어떻게 작성 하나요 ㅜㅜ from turtle import * import math r = int ( input (' 반지름 ')) while True : d = int ( input (' 도형 ')) if d & gt ;= 3 and d & lt ;= 6 : break x = int ( input (' 원 둘레 ')) if x : circle ...",
#  ' 파이썬 임의 의 난수 질문 드립니다 ! https://kin.naver.com/qna/detail.nhn?d1id=1&amp;dirId=1040201&amp;docId=401830375&amp;page=1#answer1 제 가 답변 하여 채택 된 글 입니다 . 동일한 문제 집 같습니다 .',
#  ' ... 혹시 파이썬 도 위 와 같이 창업 을 할 수 있는 방법 (?) 이 뭐 가 ... 또한 웹 이나 앱 은 1 인 개발 이 가능한데 파이썬 으로 1 인 개발 로 ... 파이썬 을 활용 한 1 인 창업 을 고민 하고 계신데요 . 파이썬 도 Django 프레임워크 를 활용 하면 웹 개발 을 할 수 ...',
#  ' 메모장 에 파이썬 에서 실행 해야 할 명령 을 적어놓고 저장 해놓았다가 파이썬 에 이를 가져와서 실행 하고 싶은데 어떻게 해야하나요 ? 질문 내용 을 보아 파이썬 코딩 을 메모장 에서 할 수 있느냐는 질문 으로 보입니다 . 메모장 에서 아래 와 ...',
#  ' 제 가 파이썬 을 공부 하고 있는데 파이썬 파일 과 같은 위치 에 & quot ; a . txt & quot ; 라는 파일 을 만들고 싶어요 . 근데 만약 이미 있으면 만들 필요 가 없어서 실행 시키지 않고 싶은데 이 걸 어떻게 할까 요 ? if 문 을 쓰면 ...',
#  ' 파이썬 질문 드려요 ㅠㅠㅠ 길이 단위 변환 하는 프로그램 을 파이썬 으로 하고 있는데 출력 을 하려고 하면 자꾸 dongDic 이 정의 되지 않았다고 오류 가 나오네요 ,,, ㅠㅠㅠㅠ 어떤 부분 이 오류 인가요 ... DongUnit 함수 에는 mm 를 ...',
#  ' 파이썬 도형 그리기 각도 계산 하는 법 알려주세요 삼각형 / 사각형 / 오각형 부탁드립니다 . turtle.circle (& lt ; 반지름 길이 & gt ;, 360 ,& lt ; 꼭짓점 개수 & gt ;) 위 와 같이 입력 하면 정다각형 을 그립니다 . #파이썬 #python',
#  ' 파이썬 에서 += 를 어떻게 읽나요 ? 전 제 이름 은 복합 연산자 , 복합 대입 연산자 입니다 세부 이름 은 모르겠네요 . 자신 에 더하기 하기 ?',
#  ' 아직 제 가 파이썬 에 대해 잘 몰라서 어디가 틀린지 ... 파이썬 을 이제 막 대학교 에서 처음 배우고 있는데 숙제 를 ... 시험 도 이제 한 달 밖에 안 남았는데 파이썬 은 벼락치기 ... 파이썬 자체 는 어려운 프로그래밍 언어 는 아닙니다 . 다만 ...',
#  ' 학교 정보 수행 이 파이썬 으로 뭐 를 만들어 오라 고 하셨는데 하나 도 모르겠어서 ... 파이썬 리스트 로 간단한 예문 하나 만 만들어 주심 감사하겠습니다 . 내공 50 걸게요 . 가능한 빨리 부탁드립니다 . import ...',
#  " 파이썬 홐자 서 공부 하는 중 인데 4-22 , 23 을 못 풀겠습니다 도와주세요 # 4.22 import datetime date = datetime.datetime.now () y , m , d = date . year , date . month , date.day print ( f ' 현재 시간 은 { y } 년 { m } 월 { d }...",
#  ' ; 를 파이썬 에서 왜 사용 하는지 역할 이 뭔 지 알려주세요 보통 프로그래밍 언어 에서 세미콜론 의 역할 은 그 문장 의 종료 를 나타냅니다 . 파이썬 같은 경우 는 굳이 안 써도 되지만 ... 그냥 실수 로 쓴 것 같아 보입니다 .',
#  ' 파이썬 공부 중 입니다 . 파이썬 은 원래 오타 한번 나서 오류 나면 첨부 터 다시 써야 되나요 ?? 씨 플 플 이나 자바 는 ... IDLE 같은 파이썬 셸 에서 하기 때문 입니다 . IDLE 같은 경우 에는 셸 에서 하지 마세요 . 셸 은 아래 의 사진 같은 화면 입니다 ....',
#  ' ... 파이썬 으로 데이터 분석 등 을 할 수 있다고도 하고 반복 작업 을 할 수 있다고 하는데 혹시 엑셀 파일 로 정리 된 ... 것 도 파이썬 으로 자동 등록 할 수 있는건 가요 ? 웹 스크 래핑 , 크 롤링 으로 가능한 내용 입니다 . 데이터 분석 도 pandas 를 ...',
#  ' 파이썬 실습 인데 특수문자 를 어떻게 공백 으로 바꾸어요 ? ㅜㅜ 음 이런 걸 말 하는건 가요 ? sp = & quot ;~!@#$%^& amp ;*-_+=(){}:;?.,& lt ;& gt ;& quot ; inputStr = input () outputStr = & quot ;& quot ; for s in inputStr : if s in sp : outputStr += & quot ; & quot ; else ...',
#  ' 사진 에 있는 파이썬 코딩 최대한 자세하게 설명 부탁드려요 가장 이해 가 안 되는 부분 은 import 아래 의 l =[ ] 이 부분 이 어떻게 쓰여지는 건지 모르겠어요 나머지 부분 도 설명 부탁드립니다 !! # 랜덤 모듈 생 성 import ...',
#  " 파이썬 으로 * ** *** **** ***** ****** ******* 이 거 코딩 어떻게 해야 하나요 ? for 랑 while 둘 다 알려주세요 ㅠㅠㅠㅠㅠ for i in range ( 7 ): print (' '*( 6 - i ), end ='') print ('* '*( i + 1 ))",
#  " ... 도와주세요 ㅜㅜ 파이썬 잘 하시는 분들 제발 ... score = int ( input (' 기초 파이썬 예상 점수 : ')) if score & gt ;= 95 : print (' 당신 의 기초 파이썬 학점 은 A + 입니다 .') elif score & gt ;= 90 : print (' 당신 의 기초 파이썬 학점 은 A ...",
#  ' 파이썬 공부 를 하는데 계속 오류 가 뜨더라구요 . avg 안 에 들어갈 값 하고 7 번째 줄 에서 계속 오류 가 ... 98 이 나와야 하는데 에러 만 뜨네요 … raise 는 파이썬 에서 예외 를 발생 시키기 위 한 키 워드 입니다 ....',
#  ' ... 최근 파이썬 언어 에 관심 이 생겨 학습 중 인 학생 입니다 . 최근 ... 저 는 파이썬 을 무료 로 받아서 사용 하고 있는데 이 것 은 ... 제 가 만약 무료 인 파이썬 을 사용 해서 모듈 이나 소프트웨어 를 제작 한 다 면 , 제 가 제작 한 제 작물 은 파이썬 ...',
#  ' 파이썬 설치 를 하려고 하는데 최신 버전 은 10 이상만 된다고 하네요 .. 윈도우 7 에 파이썬 설치 하려면 전 ... 모르겠어요 ㅠㅠㅠㅠ 파이썬 공식 홈페이지 에서 win 7 지원 하는 마지막 버전 링크 드립니다 . 64 비트 컴퓨터 ...',
#  ' 파이썬 코딩 을 시작 하려고 하는데요 유튜브 와 책 을 보면서 독학 하려 하는데 책 ( 기초 ) 과 파이썬 설치 할 때 ... 강 좌라면 노마드 코더 (https://nomadcoders.co ) 의 무료 파이썬 웹 스크 래퍼 강좌 봤고 , 그 밖에는 인터넷 특히 ...',
#  ' 제 가 파이썬 을 배워 볼까 하는데요 . 웹사이트 정도 만들려면 몇 년 걸리나요 ? 웹사이트 를 만들고 싶다면 파이썬 을 ... 파이썬 을 여쭤 보셨으니 , 이 에 맞춰 답변 드리자면 , 파이썬 에서 Django 라는 프레임워크 가 있습니다 . 파이썬 으로 ...',
#  ' 파이썬 을 혼자 해볼려고 하는데 아래 사진 들 처럼 뜨면서 실행 이 안됩니다 . 어떻게 해야 되나요 ?? visual studio ... 일단 d . py 파이썬 프로그램 은 이상 이 없고요 . 실행 한 것 을 보니 , 그 부분 이 잘 못 된 것 을 보니 , 파이썬 실행 ...',
#  ' 파이썬 을 이용 해 간단하게 rpg 형식 의 일부분 을 구현 하고 싶은데요 . 몬스터 HP = 1000 이고 파이썬 사용자 한테 직접 수치 를 입력 받아서 몬스터 HP = 0 이 될 때 까지 계속 사용자 로부터 특정 수치 를 입력 받고 ...',
#  ' 파이썬 교재 를 보는데 16 진수 출력 하는 서식 문자 는 % x 이고 16 진수 의 경우 포맷팅 에 사용 하는 표현 은 % h 라고 나와있는데 둘 이 서로 다른 게 맞나요 ? % x 가 맞아요 % h 는 hour 로 시간 을 나타내기 위해 ...',
#  " ... 파이썬 으로 이렇게 출력 되게 하려면 어떻게 해야하나요 ? 다음 과 ... center ( 24 , ' ') print ( star ) ※ 질문 주신 내용 이외 에도 , 파이썬 과 ... 참고 하시기 바랍니다 : D https://dinolabs.tistory.com/category/BLOG/ 파이썬 기초",
#  " 파이썬 문제 질문 드립니다 5.11 전번 문제 를 알아야지 정확합니다만 나름 풀이 import random n 1 = random . randint ( 11 , 99 ) n 2 = random . randint ( 11 , 99 ) dap = n 1 - n 2 idap = int ( input ( str ( n 1 )+' - '+ str ( n 2 )+' = ')) if dap ...",
#  ' ... 생겨 파이썬 을 독학 해보려 합니다 . 파이썬 은 빅데이터 에 유리하다고 들었습니다 . 독학 을 할 때 , 파이썬 으로 ... 그리고 , 파이썬 을 쓰는 가장 주된 이유 가 무엇 인가요 ? 파이썬 을 학습 후 r 언어 와 하둡 을 배우시는걸 추천 드립니다 . 파이썬 을 ...',
#  " ... 1 } 파이썬 문제 가 이렇게 되어있는데 코딩 을 어떻게 해야 할까 요 ?? # - make _ word _ count () 함수 를 ... 1 } # 파이썬 문제 가 이렇게 되어있는데 코딩 을 어떻게 해야 할까 요 ?? print ( make _ word _ count (' data ....",
#  ' ... 아니면 파이썬 공부 를 먼저 해야 할까 요 ? 파이썬 과 정보처리기사 중 고민 을 ... ◐ IT 분야 자격증 , 교육 과정 * IT 베이직 : C 언어 , 파이썬 , 자바 프로그램 등 ... R 과 파이썬 을 기본 으로 하는 과정 * 정보보안 전문가 : 시스템 과 네트워크 ...',
#  ' 15 개 의 값 을 입력 받고 , 리스트 에 저장 후 , 중복 되는 값 을 제거 한 리스트 출력 하기 파이썬 코딩 짜주세요 .. ㅠ values = [] for _ in range ( 15 ): values . append ( input ()) values = list ( set ( values ))',
#  ' 파이썬 코드 짠 걸 저장 하려면 어떻게 해야하나요 ? idle 에디터 에서 하신건 가요 ? file -& gt ; Save as 저장 할 폴더 지정 하고 ( 그냥 하시면 기본 위치 에 ) 이름 지정 하고 저장 버튼',
#  " 파이썬 이 거 어떻게 하나요 ..? import sys , os for i in ( 2 , 6 ): for j in range ( 1 , 10 ): for k in range ( i , i + 4 ): print (& quot ;{ 0 }*{ 1 }={ 2 }& quot ;. format ( k , j , k * j ), end ='\\ t ') print () print ()",
#  ' ... 그리고 파이썬 으로 1 부터 200 까지의 홀수 의 합수 짝수 의 합 수 어케 구 하나요 쉽게 설명 부탁드려요 ㅠㅠ ... 그리고 파이썬 으로 1 부터 200 까지의 홀수 의 합수 짝수 의 합 수 어케 구 하나요 쉽게 설명 부탁드려요 ㅠㅠ ...',
#  ' ... 파이썬 언어 에서 조건문 에 사용 되는 관계 연산자 중 ‘ 같지 않다 ’ 를 쓰시오 2 . 파이썬 언어 에서 조건문 에 사용 되는 관계 연가 자 중 ‘ 같다 ’ 를 쓰시오 1 . 파이썬 언어 에서 ... = 2 . 파이썬 언어 에서 조건문 에 사용 되는 관계 연가 자 중 ...',
#  ' 파이썬 에 avg () 나 average () 이런 함수 없나요 ? 파이썬 에서 평균 을 구 하는 함수 가 없습니다 . 따라서 아래 와 ... ※ 질문 주신 내용 이외 에도 , 파이썬 과 관련 하여 ... 바랍니다 : D https://dinolabs.tistory.com/category/BLOG/ 파이썬 기초',
#  " ... 점수 는 실수 나 문자 가 입력 되면 체크 하여 다시 입력 해야 한다 . 를 파이썬 으로 어떻게 나타내나요 ? scores = {' 과제 ': 0 ,' 중간 ': 0 ,' 기 말 ': 0 } for i in scores . keys (): while True : d = input (' 성적 입력 (' + i +') ') if d . isdigit ...",
#  ' 파이썬 에서 폴더 를 삭제 하려면 어떻게 해야하나요 ? rmdir () 함수 와 ... 이외 에도 , 파이썬 과 관련 하여 궁금한 것 들 이 있다면 , 아래 제 ... 참고 하시기 바랍니다 : D https://dinolabs.tistory.com/category/BLOG/ 파이썬 기초',
#  ' 파이썬 3.8 . 9 사용 중 이고 talib 모듈 파이썬 3.8 용 버전 으로 pip install 하여 . py 로는 실행 이 잘 되는데 exe 패키징 하면 실행 이 안되네요 pyinstaller 실행 될 때 사용 되는 파이썬 버전 때문 인가요 ?...',
#  ' 파이썬 인강 괜찮은 사이트 추천 해주세요 . 아이 가 배우려기 ... 설명 해주는 파이썬 인강 사이트 찾고있습니다 . 괜찮은 학원 있으면 ... 아예 파이썬 인강 보다는 기초 통합 과정 인강 을 들어 보시 는 것 도 추천 드리고 있습니다 . 아래 는 파이썬 이 ...',
#  ' 파이썬 idle 를 처음 하는데 코드 를 입력 하고 엔터 를 누른 뒤 에 확인 해보니 코드 가 틀렸는데 그럼 코드 를 어떻게 ... 파이썬 의 idle 는 두 가지 모드 가 있습니다 . 1 . 다이렉트 모드 또는 직접 모드 라고 하여 한 줄 씩 코드 를 작성 하여 ...',
#  ' 프로그래밍 좀 배워 보려고 하는데 자바 와 파이썬 중 어느 것 ... 자바 와 파이썬 중 먼저 배울 프로그래밍 언어 를 고민 하고 계시군요 . 둘 다 배우실 생각 이 시 라면 파이썬 부터 ... 둘다 쓰임 새 가 다양하고 요즘 인기 있는 언어 인데 파이썬 ...',
#  ' 파이썬 독학 하려고 하는데요 ... 내용 이 쉽지는 않겠지만 그래도 ... 요새 파이썬 독학 에 도움 이 될만 한 인강 사이트 는 어디 일까 요 ? 파이썬 독학 하려고 하시나 봐요 ! 여러가지 다양한 인강 사이트 에서 파이썬 독학 에 도움 이 되 실만 한 인강 을 ...',
#  ' 제 가 이제 파이썬 입문 했는데요 .. txt 파일 에 들어가 맨 앞 자리 숫자 를 바꾸는 프로그램 짤려는데 어케 ... 고수 님 들 알려주세요 ㅠㅠ 내공 100 검 # 제 가 이제 파이썬 입문 했는데요 .. txt 파일 에 들어가 맨 ...',
#  ' 중간 값 을 도출 하는 파이썬 에서 문자 를 작은 순서대로 나열한 것 은 알겠는데 그 다음 을 어떻게 해야 할지 모르겠 네 영 .. 구 하시는 중간 값 이 list 의 중간 에 있는 값 이 라면 아래 와 같이 구 하실 수 있습니다 ....',
#  ' ... 파이썬 초보 입니다 . c =[[ 1 , 2 ],[ 20 , 30 ]] 이라 할 때 c [ 0 ][ 1 ]+= c [ 1 ][ 1 ] print ( c ) 을 입력 시 [[ 1 , 32 ],[ 20 , 30 ]] 가 ... 파이썬 에 입력 시 32 가 나오는데 왜 32 인지 모르겠습니다 . 2 . 저 식 에서 += 는 대체 뭐 죠 ? 3 . 대체 왜 print ( c ) 가 [[ 1 ...',
#  ' 파이썬 으로 도형 그리기 에서 if 조건문 이랑 whlie 써서 저런 식 으로 프로그램 했는데 왜 오각형 만 그려질까 요 ?? 알고리즘 어떻게 짜야 하나요 ?? 박스 안 에서 무한 반복 을 하게 됩니다 . 그래서 pentagon () 만 실행 이 되고요 . 그래서 ...',
#  " 파이썬 변수 에 특수문자 지정 을 하고 싶으면 어떻게 하나요 ? 밑 처럼 했을 때 ! ! @ * # @ 이렇게 출력 되었으면 좋겠어요 for i in '!!@*#@': A = i print ( A ) #파이썬 #python for c in '!!@*#@': print ( c ) A 나 i 둘 다 ...",
#  ' 파이썬 리스트 가 예 를 들어서 A = [ 1 , 2 , 3 , 4 ] 이면 0 번 째 가 1 로 출력 되잖아요 ? 근데 리스트 를 사용 하 되 , 1 번 째 가 1 로 ... 파이썬 문법 의 근간 을 흔드는 일이 되겠네요 . 임의 적 으로 index 0 에 쓰레기 값 을 넣어서 질문 자만 알아서 사용 해야 ...',
#  " 파이썬 for 문 을 이용 해서 * *** ***** *** * 이렇게 나오게 어떻게 만드나 요 ? s = 2 x = 1 for i in range ( 1 , 6 ) : print (' ' * s , end = '') print ('*' * x ) if i & gt ;= 3 : s += 1 x -= 2 else : s -= 1 x += 2",
#  ' 파이썬 문제 질문 드립니다 ㅠㅠ 1:1 질문 답변 드립니다 . n = int ( input (& quot ;: & quot ;)) if n & gt ;= 0 and n & lt ;= 100 and n % 2 == 0 : print ( True ) else : print ( False )',
#  " 파이썬 문제 인데 모르겠어요 while True : n = input (' 이진수 입력 ') sum = 0 c = 0 for idx , d in enumerate ( n ): if d != ' 1 ' and d != ' 0 ': print (' 잘 못 된 이진수 다시 입력 ') c = 1 break if d == ' 1 ': sum += 2 ** ( len ( n )...",
#  ' 파이썬 을 이제 막 배우고 있는데요 .. gui 는 화면 을 만드는 거 라고 알고있는데 .... 굳이 , 파이썬 으로 만드는 이유 가 있나요 ? 파이썬 이란 언어 는 보이는 모양 ... 파이썬 으로 GUI 를 만드는 건 화려하고 멋진 무언가 를 만들기 위함 이 아닌 ...',
#  ' 파이썬 프로그래밍 문제 인데 도저히 모르겠어서 올립니다 ㅠ 아래 문제 해결 해주실 수 있나요 ?... 테스트 후 루프 구조 를 사용 하여 파이썬 프로그램 을 작성 하여 모집단 이 2만 명 미만 이 되려면 몇 년 이 걸릴지 ...',
#  " 위 사진 애 나오는 프로그래밍 코드 좀 짜주세요 파이썬 이고 반복 중 첩 문 사용 해주세요 age = int ( input (' 만 나이 입력 : ')) year = int ( input (' 출생 연도 끝 자리 입력 : ')) day =[' 금요일 ',' 월요일 ',' 화요일 ',' 수요일 ...",
#  ' 안녕하세요 파이썬 을 처음 시작 하는 유저 입니다 . 파이썬 에서 대표 적 으로 쓰는 라이브러리 들 은 무엇 이 있는지 ... 코드 를 개선 해나가면서 이 것 저 것 패키지 를 많이 깔아야 될텐데 일반 적 으로 파이썬 쓰시면서 많이 쓰는 것 들 은 ...',
#  " 파이썬 현재 반복 문 까지 배웠습니다 ., 이 프로그램 짜는 방법 이 너무 궁금합니다 .. 되도록 간결하고 짧게 짜주시도록 부탁드립니다 . ㅠ for i in range ( 5 ): print (& quot ; & quot ;*( 5 - i ), end ='') print (& quot ;*& quot ;*( i * 2 + 1 )) for i in range ( 4 )...",
#  ' 파이썬 독학 어떻게 해 요 ? 파이썬 이 쉽게 접 할 수 있다고는 하나 , 프로그래밍언어 에 대한 기초 적 인 지식 과 이해 가 ... 이해 가 어렵다면 , 학원 을 통해 도움 을 받으셔야 할것 같습니다 . & gt ;& gt ; 프로그래밍 과정 문의 파이썬 / 자바 / C 언어 알아보기',
#  ' 파이썬 학원 추천 좀 해주세요 올해 고 3 이고 수험 이 끝나서 ... 때 파이썬 배워 두고 가면 좋다고 해서 배워 볼 까 생각 중 입니다 . 혹시 , 서울 주변 에 파이썬 학원 으로 가장 괜찮은 ... 파이썬 과정 이 필요하셔서 공부 를 희망 하신다고 말씀 해 ...',
#  ' 파이썬 코딩 언어 (?) Input () 이나 int () 등 기초 적 으로 사용 되는것 들있잖아요 ... 지금 파이썬 공부 하려는데 저런 기초 적 인 단어 가 무슨 뜻 인지 몰라서 자꾸 ... 파이썬 공부 하실 수 있는 인강 사이트 알려 드리겠습니다 . 참고 해보세요 . 현재 ...',
#  ' 파이썬 코드 질문 드립니다 . 문자열 에서 공백 기준 으로 문자 를 다 ... 이외 에도 , 파이썬 과 관련 하여 궁금한 것 들 이 있다면 , 아래 제 블로그 에 ... 글 을 참고 하시기 바랍니다 : D https://dinolabs.tistory.com/category/BLOG/ 파이썬 기초',
#  ' 클라우드 엔지니어 에게 파이썬 코딩 능력 이 요구 되 기도 한다는데 파이썬 의 자동화 , 웹크롤러 관련 되서 나오는 이야기 ... 클라우드 기술 과 파이썬 이 구체 적 으로 어떤 연관 을 갖고 있는지 알고싶습니다 . 실제 로 클라우드 기술자 가 파이썬 을 ...',
#  " 파이썬 두 문제 질문 입니다 ㅠㅠ ! d = input (' 입력 :') if d . lower () in [' a ',' e ',' i ',' o ',' u ']: print ( f '{ d } ( 은 ) 는 모음 입니다 .') else : print ( f '{ d } ( 은 ) 는 자음 입니다 .') a , b , c = map ( int , input (' 세 ...",
#  ' 파이썬 프로그램 짜기가 수행 인데 ( for 문 , if 문 등등 등 다 사욯해 서 ) 어떻게 해야 될지 감 이 안 잡혀요 ㅠㅠㅜㅜㅜ 도와주세요 엄청 쉽고 초 등수 준이여도 괜찮아요 ㅈㅂㅈㅂ user = {} while True : choice ...',
#  ' 기초 설명 잘 해주는 파이썬 강의 찾고 있어요 . 가격 ... 계획 이라 파이썬 강의 외 에 C 언어 강의 도 수강 할 수 있는 곳 이 면 좋겠습니다 . 기초 설명 잘 해주는 파이썬 강의 찾고 ... 그리고 추후 C 언어 도 공부 할 계획 이라 파이썬 강의 외 에 ...',
#  ' 파이썬 을 처음 으로 배워 보려고 유튜브 를 따라하고 있는데 계속 해서 디버그 실행 하면 저렇게 나오고 연산 결과 가 안 나와요 .... 어떻게 해야 할까 요 ? 아래 명령 창 에 ps : c : ￦ ....& gt ; 상태 일 때 수행 하세요 아래 가 python 프롬 프트 ...',
#  " 파이썬 에서 ' True ' 라고 반환 된 값 은 문자열 데이터 인가요 ? True ', 또는 ... ※ 질문 주신 내용 이외 에도 , 파이썬 과 관련 하여 궁금한 것 들 이 있다면 ... 참고 하시기 바랍니다 : D https://dinolabs.tistory.com/category/BLOG/ 파이썬 기초",
#  ' ... 2 학기 부터 파이썬 프로그래밍 수업 을 공부 한다고 하는데 학원 에가 서 전문 적 으로 배울 수 있는 파이썬 프로그래밍 ... 파이썬 프로그래밍 수업 이 필요하셔서 교육 기관 을 을 ... ㆍ 프로그래밍언어 ( 파이썬 , C 언어 , C ++ ) ㆍ 운영체제 ...']

# %%
X = vectorizer.fit_transform(contents_for_vectorize)
X
# Out:
# <100x1067 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2222 stored elements in Compressed Sparse Row format>

# %%
num_samples, num_features = X.shape
num_samples, num_features
# Out:
# (100, 1067)

# %%
new_post = ['파이썬 독학은 어떻게 하나요']
new_post_tokens = [t.morphs(row) for row in new_post]

new_post_for_vectorize = []

for content in new_post_tokens:
    sentence = ''
    for word in content:
        sentence = sentence + ' ' + word
    
    new_post_for_vectorize.append(sentence)
    
new_post_for_vectorize
# Out:
# [' 파이썬 독학 은 어떻게 하나요']

# %%
new_post_vec = vectorizer.transform(new_post_for_vectorize)
new_post_vec.toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %%
import scipy as sp

def dist_raw(v1, v2):
    delta = v1 - v2
    return sp.linalg.norm(delta.toarray())

# %%
dist = [dist_raw(each, new_post_vec) for each in X]
dist
# Out:
# [6.708203932499369,
#  5.916079783099616,
#  10.0,
#  6.082762530298219,
#  3.872983346207417,
#  8.774964387392123,
#  7.416198487095663,
#  5.916079783099616,
#  9.38083151964686,
#  4.58257569495584,
#  6.324555320336759,
#  6.082762530298219,
#  6.48074069840786,
#  7.3484692283495345,
#  5.744562646538029,
#  5.291502622129181,
#  6.48074069840786,
#  6.708203932499369,
#  5.5677643628300215,
#  5.5677643628300215,
#  7.280109889280518,
#  5.0,
#  6.557438524302,
#  7.14142842854285,
#  6.4031242374328485,
#  5.830951894845301,
#  7.615773105863909,
#  6.855654600401044,
#  9.16515138991168,
#  6.708203932499369,
#  6.782329983125268,
#  6.48074069840786,
#  6.082762530298219,
#  6.557438524302,
#  7.0,
#  5.830951894845301,
#  6.0,
#  5.916079783099616,
#  4.795831523312719,
#  6.082762530298219,
#  5.5677643628300215,
#  6.855654600401044,
#  5.5677643628300215,
#  7.416198487095663,
#  6.48074069840786,
#  8.426149773176359,
#  6.0,
#  4.242640687119285,
#  7.745966692414834,
#  6.0,
#  6.557438524302,
#  6.164414002968976,
#  5.477225575051661,
#  6.48074069840786,
#  6.082762530298219,
#  6.48074069840786,
#  5.916079783099616,
#  5.656854249492381,
#  7.280109889280518,
#  6.928203230275509,
#  6.557438524302,
#  6.4031242374328485,
#  6.6332495807108,
#  6.164414002968976,
#  6.48074069840786,
#  7.483314773547883,
#  9.591663046625438,
#  6.4031242374328485,
#  6.082762530298219,
#  5.477225575051661,
#  6.48074069840786,
#  7.615773105863909,
#  7.280109889280518,
#  6.6332495807108,
#  7.483314773547883,
#  6.244997998398398,
#  5.5677643628300215,
#  6.324555320336759,
#  5.916079783099616,
#  5.0990195135927845,
#  5.5677643628300215,
#  4.58257569495584,
#  5.916079783099616,
#  5.830951894845301,
#  6.928203230275509,
#  5.656854249492381,
#  5.916079783099616,
#  6.164414002968976,
#  7.0710678118654755,
#  5.744562646538029,
#  6.6332495807108,
#  6.4031242374328485,
#  5.830951894845301,
#  6.6332495807108,
#  5.656854249492381,
#  5.0,
#  8.54400374531753,
#  5.830951894845301,
#  6.082762530298219,
#  6.48074069840786]

# %%
print('Best post is', dist.index(min(dist)), ', dist = ', min(dist))
print('Test post is --> ', new_post)
print('Best dist post is --> ', contents[dist.index(min(dist))])
# Out:
# Best post is 4 , dist =  3.872983346207417
# Test post is -->  ['파이썬 독학은 어떻게 하나요']
# Best dist post is -->  파이썬 for, while문 연습문제로 나와있는 건데요 위 그림 순서대로 (1),(2),(3),(4) 차례로... D:\파이썬코드\test...

# %%
min(dist)
# Out:
# 3.872983346207417

# %%
dist.index(min(dist))
# Out:
# 4

# %%
print(min(dist))
print(contents[dist.index(min(dist))])
# Out:
# 3.872983346207417
# 파이썬 for, while문 연습문제로 나와있는 건데요 위 그림 순서대로 (1),(2),(3),(4) 차례로... D:\파이썬코드\test...
